# %% [markdown]
# # DataFrame Basics Exercise

# %% [markdown]
# ## Part 1
# * Use pandas to read the `bestsellers` dataset into a DataFrame
# * Once you've done that, use Pandas to figure out how many rows and columns the DF has
# * Inspect the first 5 rows
# * Inspect the first 19 rows
# * Inspect the last 5 rows
# * Inspect the last 2 rows
# * Which columns (if any) are missing values? nope
# * What datatype did Pandas assign to "User Rating"? float64
# * How many integer columns are in the DataFrame? 3

# %%
import pandas as pd
bs = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\bestsellers.csv")
bs
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
bs.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
bs.head(19)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 17     Adult Coloring Book: Stress Relieving Patterns
# 18  Adult Coloring Books: A Coloring Book for Adul...
#
#                          Author  User Rating  Reviews  Price  Year  \
# 0                      JJ Smith          4.7    17350      8  2016
# 1                  Stephen King          4.6     2052     22  2011
# 2            Jordan B. Peterson          4.7    18979     15  2018
# 3                 George Orwell          4.7    21424      6  2017
# 4      National Geographic Kids          4.8     7665     12  2019
# 5           George R. R. Martin          4.4    12643     11  2011
# 6           George R. R. Martin          4.7    19735     30  2014
# 7                   Amor Towles          4.7    19699     15  2017
# 8                   James Comey          4.7     5983      3  2018
# 9               Fredrik Backman          4.6    23848      8  2016
# 10              Fredrik Backman          4.6    23848      8  2017
# 11             Larry Schweikart          4.6      460      2  2010
# 12                Jaycee Dugard          4.6     4149     32  2011
# 13            Madeleine L'Engle          4.5     5153      5  2018
# 14                 Steve Harvey          4.6     5013     17  2009
# 15  Adult Coloring Book Designs          4.5     2313      4  2016
# 16           Blue Star Coloring          4.6     2925      6  2015
# 17           Blue Star Coloring          4.4     2951      6  2015
# 18    Coloring Books for Adults          4.5     2426      8  2015
#
#           Genre
# 0   Non Fiction
# 1       Fiction
# 2   Non Fiction
# 3       Fiction
# 4   Non Fiction
# 5       Fiction
# 6       Fiction
# 7       Fiction
# 8   Non Fiction
# 9       Fiction
# 10      Fiction
# 11  Non Fiction
# 12  Non Fiction
# 13      Fiction
# 14  Non Fiction
# 15  Non Fiction
# 16  Non Fiction
# 17  Non Fiction
# 18  Non Fiction

# %%
bs.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
bs.tail(2)
# Out:
#                                                   Name       Author  \
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
bs.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
bs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
bs.shape
# Out:
# (550, 7)

# %% [markdown]
# ## Part 2
#
# * The `mount_everest_deaths` dataset has its own index column provided in the dataset.  When importing it, use the existing index column.
# * Which columns have zero null values? age and location
# * Which column has the most null values? age

# %%
pd.options.display.min_rows = 50
pd.options.display.max_rows = 51
med = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\mount_everest_deaths.csv',index_col = 0)
med
# Out:
#                            Name              Date   Age  \
# No.
# 1                         Dorje      June 7, 1922   NaN
# 2                        Lhakpa      June 7, 1922   NaN
# 3                         Norbu      June 7, 1922   NaN
# 4                        Pasang      June 7, 1922   NaN
# 5                          Pema      June 7, 1922   NaN
# 6                         Sange      June 7, 1922   NaN
# 7                         Temba      June 7, 1922   NaN
# 8                   Man Bahadur      May 13, 1924   NaN
# 9        Lance-Naik Shamsherpun      May 17, 1924   NaN
# 10                Andrew Irvine      June 9, 1924  22.0
# 11               George Mallory      June 9, 1924  37.0
# 12               Maurice Wilson      May 31, 1934  36.0
# 13                 Dorje Mingma  October 31, 1952   NaN
# 14                      Wang Ji    April 11, 1960   NaN
# 15               Shao Shi-Ching    April 29, 1960   NaN
# 16              Nawang Tshering    April 28, 1962   NaN
# 17             Jake Breitenbach    March 23, 1963  27.0
# 18                   Ma Gao-shu       May 1, 1966   NaN
# 19            Phu Dorjee Sherpa  October 18, 1969   NaN
# 20                   Nima Dorje     April 5, 1970   NaN
# 21                  Kunga Norbu     April 5, 1970   NaN
# 22                   Mima Norbu     April 5, 1970   NaN
# 23                       Pasang     April 5, 1970   NaN
# 24                Kami Tshering     April 5, 1970   NaN
# 25                 Kyak Tsering     April 9, 1970  36.0
# ..                          ...               ...   ...
# 286             Roland Yearwood      May 20, 2017  50.0
# 287              Vladimír Štrba      May 21, 2017  48.0
# 288  Francesco Enrico Marchetti      May 21, 2017  54.0
# 289                  Ravi Kumar      May 21, 2017  27.0
# 290             Lam Babu Sherpa      May 14, 2018  45.0
# 291         Pasang Norbu Sherpa      May 18, 2018  41.0
# 292              Gjeorgi Petkov      May 20, 2018  63.0
# 293             Nobukazu Kuriki      May 21, 2018  36.0
# 294          Damai Sarki Sherpa      May 21, 2018  37.0
# 295                  Chris Daly    April 20, 2019  35.0
# 296       Séamus (Shay) Lawless      May 16, 2019  39.0
# 297                 Ravi Thakar      May 17, 2019  28.0
# 298                 Donald Cash      May 22, 2019  55.0
# 299                Nihal Bagwan      May 23, 2019  27.0
# 300              Ernst Landgraf      May 23, 2019  65.0
# 301           Anjali S Kulkarni      May 23, 2019  54.0
# 302                Kalpana Dash      May 23, 2019  52.0
# 303                 Kevin Hynes      May 24, 2019  56.0
# 304                Dhruba Bista      May 24, 2019   NaN
# 305         Robin Haynes Fisher      May 25, 2019  44.0
# 306      Christopher Jon Kulish      May 27, 2019  62.0
# 307                   Puwei Liu      May 12, 2021  55.0
# 308               Abdul Waraich      May 12, 2021  41.0
# 309          Pemba Tashi Sherpa      May 18, 2021  28.0
# 310          Wong Dorchi Sherpa      May 23, 2021   NaN
#
#                                             Expedition      Nationality  \
# No.
# 1                1922 British Mount Everest Expedition            Nepal
# 2                1922 British Mount Everest Expedition            Nepal
# 3                1922 British Mount Everest Expedition            Nepal
# 4                1922 British Mount Everest Expedition            Nepal
# 5                1922 British Mount Everest Expedition            Nepal
# 6                1922 British Mount Everest Expedition            Nepal
# 7                1922 British Mount Everest Expedition            Nepal
# 8                1924 British Mount Everest Expedition            Nepal
# 9                1924 British Mount Everest Expedition            Nepal
# 10               1924 British Mount Everest Expedition   United Kingdom
# 11               1924 British Mount Everest Expedition   United Kingdom
# 12                                     Solo Expedition   United Kingdom
# 13                                    Swiss Expedition            Nepal
# 14                   Chinese Expedition Northern Slope            China
# 15                   Chinese Expedition Northern Slope            China
# 16                   Chinese Expedition Northern Slope            Nepal
# 17   Norman Dyhrenfurth's American Mount Everest Ex...    United States
# 18                          Chinese Everest Expedition            China
# 19                         Japanese Everest Expedition            Nepal
# 20                          Japanese Skiing Expedition            Nepal
# 21                          Japanese Skiing Expedition            Nepal
# 22                          Japanese Skiing Expedition            Nepal
# 23                          Japanese Skiing Expedition            Nepal
# 24                          Japanese Skiing Expedition            Nepal
# 25                          Japanese Skiing Expedition            Nepal
# ..                                                 ...              ...
# 286                              Everest Parivar Treks    United States
# 287            Everest Hard Way Slovak Expedition 2017         Slovakia
# 288                                Expedition Himalaya        Australia
# 289                          Arun Treks and Expedition            India
# 290                                 Seven Summit Treks            Nepal
# 291                          7 Summits Club Expedition            Nepal
# 292        Tim Mosedale Everest Expedition Spring 2018  North Macedonia
# 293                                               Solo            Japan
# 294               Himalayan Ascent, Seven Summit Treks            Nepal
# 295                                               Solo    United States
# 296                                 Seven Summit Treks          Ireland
# 297                                 Seven Summit Treks            India
# 298                                 Pioneer Adventures    United States
# 299                                    Peak Promotions            India
# 300                                  Kobler & Partners          Austria
# 301                            Transcent or Arun Treks            India
# 302                         Dreamers Destination Treks            India
# 303                                    360 Expeditions          Ireland
# 304                      Himalayan Ecstasy (Ski) Treks            Nepal
# 305       Summit Climb/ Everest Parivar Expedition Ltd   United Kingdom
# 306                         Climbing the Seven Summits    United States
# 307                                 Seven Summit Treks    United States
# 308                                 Seven Summit Treks      Switzerland
# 309                         Climbing the Seven Summits            Nepal
# 310                                     7 Summits Club            Nepal
#
#                                         Cause of death  \
# No.
# 1                                            Avalanche
# 2                                            Avalanche
# 3                                            Avalanche
# 4                                            Avalanche
# 5                                            Avalanche
# 6                                            Avalanche
# 7                                            Avalanche
# 8                                            Pneumonia
# 9                                     Brain hemorrhage
# 10                           Unknown. Body never found
# 11   Possible ice axe injury following a fall. Body...
# 12   Possible exhaustion, exposure or starvation. B...
# 13                                         Falling ice
# 14                                   Mountain sickness
# 15                                                 NaN
# 16                                                 NaN
# 17                                 Crushed under serac
# 18                                                Fall
# 19                                Fall into a crevasse
# 20                                           Avalanche
# 21                                           Avalanche
# 22                                           Avalanche
# 23                                           Avalanche
# 24                                           Avalanche
# 25                                             by fall
# ..                                                 ...
# 286                                  Altitude sickness
# 287                                  Altitude sickness
# 288                                  Altitude sickness
# 289                          Fall into a 200m crevasse
# 290  Disappearance (reportedly suffered from snow b...
# 291                                             Stroke
# 292                                     Cardiac arrest
# 293  Hypothermia, had previously reported "persiste...
# 294                               Fall into a crevasse
# 295  Died after a fall while trekking down from bas...
# 296                           Presumed dead after fall
# 297                                  Altitude sickness
# 298                                  Altitude sickness
# 299                              Exhaustion on descent
# 300                              Exhaustion on descent
# 301                              Exhaustion on descent
# 302                              Exhaustion on descent
# 303                                  Altitude sickness
# 304                   Exhaustion and altitude sickness
# 305                          Exhaustion during descent
# 306                       Cardiac event during descent
# 307                                         Exhaustion
# 308                                         Exhaustion
# 309                               Fall into a crevasse
# 310                                                NaN
#
#                                          Location
# No.
# 1                                 Below North Col
# 2                                 Below North Col
# 3                                 Below North Col
# 4                                 Below North Col
# 5                                 Below North Col
# 6                                 Below North Col
# 7                                 Below North Col
# 8                              Above Rongbuk B.C.
# 9                              Above Rongbuk B.C.
# 10                                     N.E. Ridge
# 11                                     N.E. Ridge
# 12                           East Rongbuk Glacier
# 13                                    Lhotse Face
# 14                                            NaN
# 15                                     N.E. Ridge
# 16                                    Lhotse face
# 17                                        Icefall
# 18                                        Icefall
# 19                                        Icefall
# 20                                        Icefall
# 21                                            NaN
# 22                                        Icefall
# 23                                        Icefall
# 24                                        Icefall
# 25                                         5525 m
# ..                                            ...
# 286                                       Balcony
# 287                          Camp IV, in the tent
# 288                                       Camp IV
# 289                                       Balcony
# 290                               Above South Col
# 291                              8550m N.E. Ridge
# 292                                Above Camp III
# 293                                       Camp II
# 294                                       Camp II
# 295                                     Base Camp
# 296                                       Balcony
# 297                                        Camp 4
# 298                                  Hillary Step
# 299                                near South Col
# 300           Tibet side at 8600m after summiting
# 301                                  Near Camp IV
# 302                                  Near Balcony
# 303                                     North Col
# 304  Base Camp following evacuation from Camp III
# 305                         100 metres below peak
# 306                                     South Col
# 307                             Near South Summit
# 308                             Near South Summit
# 309                      Between Camp I & Camp II
# 310                                near South Col
#
# [310 rows x 7 columns]

# %% [markdown]
# ## Part 3
# * Import the `movie_titles.tsv` dataset
# * You'll notice that it is not comma-separated! You'll need to tell `read_csv` what the separator actually is.
# * The dataset does not come with its own column headings, so you'll need to provide those as well.  The columns are, in order, `id`, `title`, `year`, `imdb_rating`, `imdb_id`, and `genres`
# * Once you have successfully read the dataset into a DataFrame, inspect the last 7 rows!

# %%
mv = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\movie_titles.tsv",sep = "	" ,names = ['id', "title", 'year', 'imdb_rating', 'imdb_id','genres'])
mv
# Out:
#        id                                          title    year  imdb_rating  \
# 0      m0                     10 things i hate about you    1999          6.9
# 1      m1                     1492: conquest of paradise    1992          6.2
# 2      m2                                     15 minutes    2001          6.1
# 3      m3                          2001: a space odyssey    1968          8.4
# 4      m4                                        48 hrs.    1982          6.9
# 5      m5                              the fifth element    1997          7.5
# 6      m6                                            8mm    1999          6.3
# 7      m7  a nightmare on elm street 4: the dream master    1988          5.2
# 8      m8     a nightmare on elm street: the dream child    1989          4.7
# 9      m9                           the atomic submarine    1959          4.9
# 10    m10                                     affliction    1997          6.9
# 11    m11                                  air force one    1997          6.3
# 12    m12                        airplane ii: the sequel    1982          5.8
# 13    m13                                      airplane!    1980          7.8
# 14    m14                                   alien nation    1988          6.1
# 15    m15                                         aliens    1986          8.5
# 16    m16                                        amadeus    1984          8.4
# 17    m17                 an american werewolf in london    1981          7.5
# 18    m18                               american madness    1932          7.4
# 19    m19                               american outlaws    2001          5.7
# 20    m20                                american psycho    2000          7.4
# 21    m21                                      antitrust    2001          6.0
# 22    m22    austin powers: international man of mystery    1997          7.1
# 23    m23                                   the avengers    1998          3.4
# 24    m24                                 bachelor party    1984          5.9
# ..    ...                                            ...     ...          ...
# 592  m592                             the usual suspects    1995          8.7
# 593  m593                                        verdict    1974          5.7
# 594  m594                                        vertigo    1958          8.6
# 595  m595                                very bad things    1998          6.0
# 596  m596                                      viridiana    1961          8.2
# 597  m597                                     virtuosity    1995          5.3
# 598  m598                                    wag the dog    1997          7.1
# 599  m599                                    wall street    1987          7.3
# 600  m600                                        waxwork    1988          6.0
# 601  m601                              what lies beneath    2000          6.5
# 602  m602                                what women want    2000          6.3
# 603  m603                              the witching hour    1996          6.5
# 604  m604                                    white angel    1994          4.4
# 605  m605                              who's your daddy?  2003/I          4.5
# 606  m606                                    wild things    1998          6.6
# 607  m607                                 wild wild west    1999          4.3
# 608  m608                                         willow    1988          7.1
# 609  m609                                        witness    1985          7.6
# 610  m610                               the wizard of oz    1939          8.3
# 611  m611                        the world is not enough    1999          6.3
# 612  m612                                       watchmen    2009          7.8
# 613  m613                                            xxx    2002          5.6
# 614  m614                                          x-men    2000          7.4
# 615  m615                             young frankenstein    1974          8.0
# 616  m616                                      zulu dawn    1979          6.4
#
#       imdb_id                                             genres
# 0     62847.0                               ['comedy' 'romance']
# 1     10421.0        ['adventure' 'biography' 'drama' 'history']
# 2     25854.0              ['action' 'crime' 'drama' 'thriller']
# 3    163227.0                   ['adventure' 'mystery' 'sci-fi']
# 4     22289.0     ['action' 'comedy' 'crime' 'drama' 'thriller']
# 5    133756.0  ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# 6     48212.0                     ['crime' 'mystery' 'thriller']
# 7     13590.0                    ['fantasy' 'horror' 'thriller']
# 8     11092.0                    ['fantasy' 'horror' 'thriller']
# 9       513.0                              ['sci-fi' 'thriller']
# 10     7252.0                     ['drama' 'mystery' 'thriller']
# 11    61978.0                      ['action' 'drama' 'thriller']
# 12    15210.0                      ['comedy' 'romance' 'sci-fi']
# 13    57692.0                               ['comedy' 'romance']
# 14     5590.0              ['crime' 'drama' 'sci-fi' 'thriller']
# 15   173518.0                     ['action' 'sci-fi' 'thriller']
# 16    99138.0                      ['biography' 'drama' 'music']
# 17    24443.0                               ['horror' 'romance']
# 18      702.0                                          ['drama']
# 19     7425.0                               ['action' 'western']
# 20   101357.0                               ['drama' 'thriller']
# 21    16453.0                               ['drama' 'thriller']
# 22    75240.0            ['action' 'adventure' 'comedy' 'crime']
# 23    21519.0                  ['action' 'adventure' 'thriller']
# 24    14050.0                               ['comedy' 'romance']
# ..        ...                                                ...
# 592  272137.0                     ['crime' 'mystery' 'thriller']
# 593     135.0                                          ['drama']
# 594   93524.0           ['crime' 'mystery' 'romance' 'thriller']
# 595   22977.0                      ['comedy' 'crime' 'thriller']
# 596    6288.0                                          ['drama']
# 597   11191.0             ['action' 'crime' 'sci-fi' 'thriller']
# 598   36448.0                                 ['comedy' 'drama']
# 599   39082.0                                  ['crime' 'drama']
# 600    2596.0                      ['comedy' 'fantasy' 'horror']
# 601   46195.0            ['drama' 'horror' 'mystery' 'thriller']
# 602   55269.0                     ['comedy' 'fantasy' 'romance']
# 603      69.0                            ['documentary' 'short']
# 604      99.0                               ['drama' 'thriller']
# 605    2267.0                                         ['comedy']
# 606   40523.0                     ['crime' 'mystery' 'thriller']
# 607   54943.0             ['action' 'western' 'comedy' 'sci-fi']
# 608   33506.0  ['action' 'adventure' 'drama' 'fantasy' 'roman...
# 609   30705.0                     ['drama' 'romance' 'thriller']
# 610  104873.0         ['adventure' 'family' 'fantasy' 'musical']
# 611   60047.0                  ['action' 'adventure' 'thriller']
# 612  135229.0  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613   53505.0                     ['action' 'adventure' 'crime']
# 614  122149.0                                ['action' 'sci-fi']
# 615   57618.0                                ['comedy' 'sci-fi']
# 616    1911.0     ['action' 'adventure' 'drama' 'history' 'war']
#
# [617 rows x 6 columns]

# %%
mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           617 non-null    object
#  1   title        616 non-null    object
#  2   year         616 non-null    object
#  3   imdb_rating  616 non-null    float64
#  4   imdb_id      616 non-null    float64
#  5   genres       616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.0+ KB

# %%
mv.tail(7)
# Out:
#        id                    title  year  imdb_rating   imdb_id  \
# 610  m610         the wizard of oz  1939          8.3  104873.0
# 611  m611  the world is not enough  1999          6.3   60047.0
# 612  m612                 watchmen  2009          7.8  135229.0
# 613  m613                      xxx  2002          5.6   53505.0
# 614  m614                    x-men  2000          7.4  122149.0
# 615  m615       young frankenstein  1974          8.0   57618.0
# 616  m616                zulu dawn  1979          6.4    1911.0
#
#                                                 genres
# 610         ['adventure' 'family' 'fantasy' 'musical']
# 611                  ['action' 'adventure' 'thriller']
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']
