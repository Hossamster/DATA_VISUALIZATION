# %%
import pandas as pd

# %%
titanic = pd.read_csv(r'D:\mygithub\data_visualization\data\titanic.csv')

# %%
titanic['age'] = titanic['age'].replace(['?'],[None]).astype('float')

# %%
titanic['fare'] = titanic['fare'].replace(['?'],[None]).astype('float')

# %%
titanic['name'][0] = [1,2,3]
# Out:
# C:\Users\Hossam\AppData\Local\Temp\ipykernel_14072\795162995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['name'][0] = [1,2,3]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                        [1, 2, 3]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['name'][0]
# its not a string only column, we can put anything that is not a string
# Out:
# [1, 2, 3]

# %%
titanic['name'].astype('string')
# Out:
# 0                                             [1, 2, 3]
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: string

# %%
titanic['name'].astype('string')[0]
# now it is string
# Out:
# '[1, 2, 3]'

# %%
titanic['name']
# Out:
# 0                                             [1, 2, 3]
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\mygithub\data_visualization\pandas_17.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_17.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> titanic['name'].upper()
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %% [markdown]
# ### Methods like upper or lower are not supported by series
# #### So what is the solution ?

# %%
titanic['name'].str.upper()
# Out:
# 0                                                   NaN
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].str.lower()
# Out:
# 0                                                   NaN
# 1                        allison, master. hudson trevor
# 2                          allison, miss. helen loraine
# 3                  allison, mr. hudson joshua creighton
# 4       allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               zabour, miss. hileni
# 1305                              zabour, miss. thamine
# 1306                          zakarian, mr. mapriededer
# 1307                                zakarian, mr. ortin
# 1308                                 zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['lower_name'] = titanic['name'].str.lower()

# %%
titanic['lower_name']
# Out:
# 0                                                   NaN
# 1                        allison, master. hudson trevor
# 2                          allison, miss. helen loraine
# 3                  allison, mr. hudson joshua creighton
# 4       allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               zabour, miss. hileni
# 1305                              zabour, miss. thamine
# 1306                          zakarian, mr. mapriededer
# 1307                                zakarian, mr. ortin
# 1308                                 zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %%
titanic['lower_name'].str.capitalize()
# Out:
# 0                                                   NaN
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %%
titanic['cabin']
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic['cabin'][0]
# Out:
# 'B5'

# %%
titanic['cabin'].str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic['deck'] = titanic['cabin'].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                        [1, 2, 3]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby('deck').mean()
# Out:
#         pclass  survived        age     sibsp     parch        fare
# deck
# ?     2.617357  0.302761  27.406654  0.503945  0.367850   19.132707
# A     1.000000  0.500000  44.157895  0.181818  0.181818   41.244314
# B     1.000000  0.723077  36.476190  0.446154  0.661538  122.383078
# C     1.000000  0.606383  38.382752  0.680851  0.414894  107.926598
# D     1.130435  0.695652  39.702381  0.413043  0.260870   53.007339
# E     1.243902  0.731707  38.118421  0.341463  0.390244   54.564634
# F     2.380952  0.619048  21.333333  0.428571  0.523810   18.079367
# G     3.000000  0.600000  12.000000  0.600000  1.200000   14.205000
# T     1.000000  0.000000  45.000000  0.000000  0.000000   35.500000

# %%
titanic.groupby('deck')['survived'].mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='deck'>

# %%
titanic['cabin'].str[1:]
# Out:
# 0            5
# 1       22 C26
# 2       22 C26
# 3       22 C26
# 4       22 C26
#          ...
# 1304
# 1305
# 1306
# 1307
# 1308
# Name: cabin, Length: 1309, dtype: object

# %%
s = pd.Series(['1. Hawk.  ','2. Pickle!\n','3. Melonhead?\t'])

# %%
s
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip("1 H")
# Out:
# 0            . Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.rstrip(to_strip = '\n \t')
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
titanic['home.dest']
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic['home.dest'].str.split('/')
# Out:
# 0                           [St Louis, MO]
# 1       [Montreal, PQ ,  Chesterville, ON]
# 2       [Montreal, PQ ,  Chesterville, ON]
# 3       [Montreal, PQ ,  Chesterville, ON]
# 4       [Montreal, PQ ,  Chesterville, ON]
#                        ...
# 1304                                   [?]
# 1305                                   [?]
# 1306                                   [?]
# 1307                                   [?]
# 1308                                   [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic['home.dest'].str.split('/')[1]
# Out:
# ['Montreal, PQ ', ' Chesterville, ON']

# %%
titanic['home.dest'].str.split('/',expand = True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic['home.dest'].str.split('/',expand = True)[0]
# Out:
# 0        St Louis, MO
# 1       Montreal, PQ
# 2       Montreal, PQ
# 3       Montreal, PQ
# 4       Montreal, PQ
#             ...
# 1304                ?
# 1305                ?
# 1306                ?
# 1307                ?
# 1308                ?
# Name: 0, Length: 1309, dtype: object

# %%
titanic['home'] = titanic['home.dest'].str.split('/',expand = True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                        [1, 2, 3]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['destination'] = titanic['home.dest'].str.split('/',expand = True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                        [1, 2, 3]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['home'].value_counts()
# Out:
# ?                                564
# New York, NY                      64
# Cornwall                          19
# London                            14
# London                            13
#                                 ...
# Chelsea, London                    1
# Harrow-on-the-Hill, Middlesex      1
# Copenhagen, Denmark                1
# Frankfort, KY                      1
# Antwerp, Belgium                   1
# Name: home, Length: 339, dtype: int64

# %%
titanic['destination'].value_counts()
# Out:
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Rochester, NY       1
#   New York, NY       1
#  Pennsylvania        1
#  Toledo, OH          1
#  Stanton, OH         1
# Name: destination, Length: 77, dtype: int64

# %%
titanic['home.dest'].str.split('/',expand = True,n = 1) # split at most once
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %%
titanic['cabin'].replace('?','???')
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %%
ufos = pd.read_csv(r'D:\mygithub\data_visualization\data\nuforc_reports.csv')

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos['duration']
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos['duration'].str.replace('seconds','s')
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos['duration'].str.replace('seconds|minutes','',regex = True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo): # reo > regular expression object
    return reo.group()[0]

# %%
ufos['duration'].str.replace('seconds|minutes|houers',abbrv,regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos['duration'].str.contains('5')
# Out:
# 0         True
# 1         True
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos['duration'].str.contains('5')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\mygithub\data_visualization\pandas_17.ipynb Cell 66 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_17.ipynb#Y131sZmlsZQ%3D%3D?line=0'>1</a> ufos[ufos['duration'].str.contains('5')]
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# ...

# %%
ufos[ufos['duration'].str.contains('5',na= False)]
# Out:
#                                                  summary         city state  \
# 0      My wife was driving southeast on a fairly popu...      Chester    VA
# 1      I think that I may caught a UFO on the NBC Nig...   Rocky Hill    CT
# 5      The object has flashing lights that are green,...   Kirbyville    TX
# 6      Description is the same as Washington DC event...       Tucson    AZ
# 15        Strange bright light hovered over mobile home.   Gray Court    SC
# ...                                                  ...          ...   ...
# 88087                 Several orange objects seen in sky     Hartford    CT
# 88090  Black triangle, no sound, no lights, flew from...      Dunedin    FL
# 88096  Shooting star that slows down to an almost com...  Great Falls    MT
# 88097                             Hovering band of light     Columbia    NJ
# 88116  Stepped out into our backyard to let out the d...  Clarksville    AR
#
#                  date_time     shape     duration  \
# ...

# %%
ufos[ufos['duration'].str.contains('hour|minute|second',na = False,regex=True)] # Regular expression
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# 5      The object has flashing lights that are green,...      Kirbyville
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...
