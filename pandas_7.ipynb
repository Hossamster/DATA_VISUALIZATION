# %%
import pandas as pd

# %%
btc = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\coin_Bitcoin.csv")
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
btc.index
# Out:
# RangeIndex(start=0, stop=2991, step=1)

# %%
btc.set_index("Date")
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.set_index('Date',inplace=True)

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc.index
# Out:
# Index(['2013-04-29 23:59:59', '2013-04-30 23:59:59', '2013-05-01 23:59:59',
#        '2013-05-02 23:59:59', '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#        '2013-05-05 23:59:59', '2013-05-06 23:59:59', '2013-05-07 23:59:59',
#        '2013-05-08 23:59:59',
#        ...
#        '2021-06-27 23:59:59', '2021-06-28 23:59:59', '2021-06-29 23:59:59',
#        '2021-06-30 23:59:59', '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#        '2021-07-03 23:59:59', '2021-07-04 23:59:59', '2021-07-05 23:59:59',
#        '2021-07-06 23:59:59'],
#       dtype='object', name='Date', length=2991)

# %%
btc.High
# Out:
# Date
# 2013-04-29 23:59:59      147.488007
# 2013-04-30 23:59:59      146.929993
# 2013-05-01 23:59:59      139.889999
# 2013-05-02 23:59:59      125.599998
# 2013-05-03 23:59:59      108.127998
#                            ...
# 2021-07-02 23:59:59    33939.588699
# 2021-07-03 23:59:59    34909.259899
# 2021-07-04 23:59:59    35937.567147
# 2021-07-05 23:59:59    35284.344430
# 2021-07-06 23:59:59    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.High.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
countries =pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\world-happiness-report-2021.csv')

# %%
countries.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
countries.set_index('Country name',inplace  = True)

# %%
countries.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
countries['Healthy life expectancy'].head().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Country name'>

# %%
countries[['lowerwhisker','Logged GDP per capita']]
# Out:
#               lowerwhisker  Logged GDP per capita
# Country name
# Finland              7.780                 10.775
# Denmark              7.552                 10.933
# Switzerland          7.500                 11.117
# Iceland              7.438                 10.878
# Netherlands          7.410                 10.932
# ...                    ...                    ...
# Lesotho              3.276                  7.926
# Botswana             3.322                  9.782
# Rwanda               3.282                  7.676
# Zimbabwe             3.030                  7.943
# Afghanistan          2.449                  7.695
#
# [149 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\world-happiness-report-2021.csv",index_col = 'Country name')
df
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
df = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\world-happiness-report-2021.csv")

# %%
df.set_index('Country name', inplace = True)

# %%
df
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.sort_values("Healthy life expectancy")
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Chad                       Sub-Saharan Africa         4.355
# Lesotho                    Sub-Saharan Africa         3.512
# Nigeria                    Sub-Saharan Africa         4.759
# Ivory Coast                Sub-Saharan Africa         5.306
# Swaziland                  Sub-Saharan Africa         4.308
# ...                                       ...           ...
# Switzerland                    Western Europe         7.571
# Spain                          Western Europe         6.491
# Japan                               East Asia         5.940
# Hong Kong S.A.R. of China           East Asia         5.477
# Singapore                      Southeast Asia         6.377
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Chad                                                0.094         4.540
# ...

# %%
countries.sort_values("Healthy life expectancy",ascending=False,inplace = True)

# %%
countries
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %%
houses = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\kc_house_data.csv')
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.sort_values('price',ascending = False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
houses.sort_values(["bedrooms",'bathrooms'],ascending = False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
titanic = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\titanic.csv")
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values('name')
# Out:
#       pclass  survived                                           name     sex  \
# 600        3         0                            Abbing, Mr. Anthony    male
# 601        3         0                  Abbott, Master. Eugene Joseph    male
# 602        3         0                    Abbott, Mr. Rossmore Edward    male
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  female
# 604        3         1                    Abelseth, Miss. Karen Marie  female
# ...      ...       ...                                            ...     ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 1262       3         0            van Billiard, Master. James William    male
# 1263       3         0              van Billiard, Master. Walter John    male
# 1264       3         0                van Billiard, Mr. Austin Blyler    male
# 1268       3         0                    van Melkebeke, Mr. Philemon    male
#
# ...

# %%
titanic.sort_values('name',key = lambda col : col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
countries.set_index('Country name', inplace = True)

# %%
countries.sort_index(inplace = True)

# %%
countries
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_index(ascending = False)
# Out:
#       pclass  survived                                             name  \
# 1308       3         0                               Zimmerman, Mr. Leo
# 1307       3         0                              Zakarian, Mr. Ortin
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1305       3         0                            Zabour, Miss. Thamine
# 1304       3         0                             Zabour, Miss. Hileni
# ...      ...       ...                                              ...
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 2          1         0                     Allison, Miss. Helen Loraine
# 1          1         1                   Allison, Master. Hudson Trevor
# 0          1         1                    Allen, Miss. Elisabeth Walton
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.pclass
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64

# %%
titanic.pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
titanic.pclass.value_counts().sort_values()
# Out:
# 2    277
# 1    323
# 3    709
# Name: pclass, dtype: int64

# %%
titanic.pclass.value_counts().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
titanic.pclass.value_counts().sort_index()
# Out:
# 1    323
# 2    277
# 3    709
# Name: pclass, dtype: int64

# %%
titanic.pclass.value_counts().sort_index().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().sort_values()
# Out:
# 11       1
# 33       1
# 10       3
# 9        6
# 0       13
# 8       13
# 7       38
# 1      199
# 6      272
# 5     1601
# 2     2760
# 4     6882
# 3     9824
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().sort_index()
# Out:
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().sort_index().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
countries.head()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# Albania                                0.059         5.234         5.001
# Algeria                                0.053         4.991         4.783
# Argentina                              0.056         6.040         5.819
# Armenia                                0.058         5.397         5.168
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc['Algeria']
# law 3ayz tegeb el row
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         4.887
# Standard error of ladder score                                       0.053
# upperwhisker                                                         4.991
# lowerwhisker                                                         4.783
# Logged GDP per capita                                                9.342
# Social support                                                       0.802
# Healthy life expectancy                                             66.005
# Freedom to make life choices                                          0.48
# Generosity                                                          -0.067
# Perceptions of corruption                                            0.752
# Ladder score in Dystopia                                              2.43
# ...

# %%
# tab law 3ayz ka dataframe
countries.loc[['Algeria']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Algeria       Middle East and North Africa         4.887
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Algeria                                0.053         4.991         4.783
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Algeria                       9.342           0.802                   66.005
#
#               Freedom to make life choices  Generosity  \
# Country name
# Algeria                               0.48      -0.067
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Algeria                           0.752                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Algeria                                  0.946                         0.765
#
# ...

# %%
countries.loc[['Egypt','Algeria']]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Egypt         Middle East and North Africa         4.283
# Algeria       Middle East and North Africa         4.887
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Egypt                                  0.045         4.371         4.195
# Algeria                                0.053         4.991         4.783
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Egypt                         9.367           0.750                   61.998
# Algeria                       9.342           0.802                   66.005
#
#               Freedom to make life choices  Generosity  \
# Country name
# Egypt                                0.749      -0.182
# Algeria                              0.480      -0.067
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.loc[[6,1308]]
# Out:
#       pclass  survived                               name     sex age  sibsp  \
# 6          1         1  Andrews, Miss. Kornelia Theodosia  female  63      1
# 1308       3         0                 Zimmerman, Mr. Leo    male  29      0
#
#       parch  ticket     fare cabin embarked boat body   home.dest
# 6         0   13502  77.9583    D7        S   10    ?  Hudson, NY
# 1308      0  315082    7.875     ?        S    ?    ?           ?

# %%
titanic.loc[5:10]
# Out:
#     pclass  survived                                           name     sex  \
# 5        1         1                            Anderson, Mr. Harry    male
# 6        1         1              Andrews, Miss. Kornelia Theodosia  female
# 7        1         0                         Andrews, Mr. Thomas Jr    male
# 8        1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1         0                        Artagaveytia, Mr. Ramon    male
# 10       1         0                         Astor, Col. John Jacob    male
#
#    age  sibsp  parch    ticket     fare    cabin embarked boat body  \
# 5   48      0      0     19952    26.55      E12        S    3    ?
# 6   63      1      0     13502  77.9583       D7        S   10    ?
# 7   39      0      0    112050        0      A36        S    ?    ?
# 8   53      2      0     11769  51.4792     C101        S    D    ?
# 9   71      0      0  PC 17609  49.5042        ?        C    ?   22
# ...

# %%
titanic.loc[5:10:2]
# Out:
#    pclass  survived                     name   sex age  sibsp  parch  \
# 5       1         1      Anderson, Mr. Harry  male  48      0      0
# 7       1         0   Andrews, Mr. Thomas Jr  male  39      0      0
# 9       1         0  Artagaveytia, Mr. Ramon  male  71      0      0
#
#      ticket     fare cabin embarked boat body            home.dest
# 5     19952    26.55   E12        S    3    ?         New York, NY
# 7    112050        0   A36        S    ?    ?          Belfast, NI
# 9  PC 17609  49.5042     ?        C    ?   22  Montevideo, Uruguay

# %%
countries.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
countries.loc['Algeria':'Egypt']
# Out:
#                                         Regional indicator  Ladder score  \
# Country name
# Algeria                       Middle East and North Africa         4.887
# Argentina                      Latin America and Caribbean         5.929
# Armenia                 Commonwealth of Independent States         5.283
# Australia                            North America and ANZ         7.183
# Austria                                     Western Europe         7.268
# Azerbaijan              Commonwealth of Independent States         5.171
# Bahrain                       Middle East and North Africa         6.647
# Bangladesh                                      South Asia         5.025
# Belarus                 Commonwealth of Independent States         5.534
# Belgium                                     Western Europe         6.834
# Benin                                   Sub-Saharan Africa         5.045
# Bolivia                        Latin America and Caribbean         5.716
# ...

# %%
#law ana 3ayz maslan el row 20 w ana msh 3aref hwa anhy country
countries.iloc[[20,54,78]]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Cambodia         Southeast Asia         4.830                           0.067
# Iceland          Western Europe         7.554                           0.059
# Luxembourg       Western Europe         7.324                           0.037
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Cambodia             4.963         4.698                  8.360
# Iceland              7.670         7.438                 10.878
# Luxembourg           7.396         7.252                 11.647
#
#               Social support  Healthy life expectancy  \
# Country name
# Cambodia               0.765                     62.0
# Iceland                0.983                     73.0
# Luxembourg             0.908                     72.6
#
#               Freedom to make life choices  Generosity  \
# Country name
# Cambodia                             0.959       0.034
# ...

# %%
countries.iloc[10:23]
# Out:
#                                         Regional indicator  Ladder score  \
# Country name
# Belarus                 Commonwealth of Independent States         5.534
# Belgium                                     Western Europe         6.834
# Benin                                   Sub-Saharan Africa         5.045
# Bolivia                        Latin America and Caribbean         5.716
# Bosnia and Herzegovina          Central and Eastern Europe         5.813
# Botswana                                Sub-Saharan Africa         3.467
# Brazil                         Latin America and Caribbean         6.330
# Bulgaria                        Central and Eastern Europe         5.266
# Burkina Faso                            Sub-Saharan Africa         4.834
# Burundi                                 Sub-Saharan Africa         3.775
# Cambodia                                    Southeast Asia         4.830
# Cameroon                                Sub-Saharan Africa         5.142
# ...

# %%
houses.sort_index(ascending=False,inplace = True)

# %%
houses.head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000  325000.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21609         2310      5813     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21612        1020              0      2008             0    98144  47.5941
# ...

# %%
houses.iloc[0:5]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000  325000.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21609         2310      5813     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21612        1020              0      2008             0    98144  47.5941
# ...

# %%
houses.loc[21612:21608]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21612  1523300157  20141015T000000  325000.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21612         1020      1076     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21609         2310      5813     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21612        1020              0      2008             0    98144  47.5941
# ...

# %%
# loc >> betbos 3ala el row el enta da5alto
# iloc >> betbos 3ala el positions ely enta da5alataha

# %%
houses.sort_index(ascending=True,inplace=True)

# %%
houses.loc[24:29,['bedrooms','bathrooms']]
# Out:
#     bedrooms  bathrooms
# 24         3       2.25
# 25         3       2.00
# 26         3       1.75
# 27         3       1.00
# 28         3       1.75
# 29         4       2.50

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc.loc[["2021-07-02 23:59:59"]]
# Out:
#                       SNo     Name Symbol          High          Low  \
# Date
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.68078
#
#                              Open        Close        Volume     Marketcap
# Date
# 2021-07-02 23:59:59  33549.600177  33897.04859  3.872897e+10  6.354508e+11

# %%
btc.iloc[0:10]
# Out:
#                      SNo     Name Symbol        High         Low        Open  \
# Date
# 2013-04-29 23:59:59    1  Bitcoin    BTC  147.488007  134.000000  134.444000
# 2013-04-30 23:59:59    2  Bitcoin    BTC  146.929993  134.050003  144.000000
# 2013-05-01 23:59:59    3  Bitcoin    BTC  139.889999  107.720001  139.000000
# 2013-05-02 23:59:59    4  Bitcoin    BTC  125.599998   92.281898  116.379997
# 2013-05-03 23:59:59    5  Bitcoin    BTC  108.127998   79.099998  106.250000
# 2013-05-04 23:59:59    6  Bitcoin    BTC  115.000000   92.500000   98.099998
# 2013-05-05 23:59:59    7  Bitcoin    BTC  118.800003  107.142998  112.900002
# 2013-05-06 23:59:59    8  Bitcoin    BTC  124.663002  106.639999  115.980003
# 2013-05-07 23:59:59    9  Bitcoin    BTC  113.444000   97.699997  112.250000
# 2013-05-08 23:59:59   10  Bitcoin    BTC  115.779999  109.599998  109.599998
#
#                           Close  Volume     Marketcap
# Date
# 2013-04-29 23:59:59  144.539993     0.0  1.603769e+09
# ...

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.loc[50:60:2,['name','sex']]
# Out:
#                                                  name     sex
# 50  Cardeza, Mrs. James Warburton Martinez (Charlo...  female
# 52                            Carrau, Mr. Francisco M    male
# 54                Carter, Master. William Thornton II    male
# 56                         Carter, Mr. William Ernest    male
# 58                             Case, Mr. Howard Brown    male
# 60                      Cavendish, Mr. Tyrell William    male

# %%
houses['bedrooms'].value_counts().iloc[0]
# Out:
# 9824

# %%
houses['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses['bedrooms'].value_counts().loc[33]
# Out:
# 1

# %%
titanic['age'].value_counts().loc["18"]
# Out:
# 39

# %%
titanic['age'].value_counts().iloc[0:5]
# Out:
# ?     263
# 24     47
# 22     43
# 21     41
# 30     40
# Name: age, dtype: int64
