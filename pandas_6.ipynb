# %%
import pandas as pd 
houses = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\kc_house_data.csv')
titanic = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\titanic.csv")
netflix = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\netflix_titles.csv",sep = '|',index_col = 0)

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic['name'].head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
titanic['home.dest']
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
mystery_col = 'price'
houses[mystery_col]
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %% [markdown]
# ### data frame is 2 dimensional data structure and the series is one dimensional data structure

# %%
names = titanic['name']

# %%
names
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
names.shape
# Out:
# (1309,)

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
names.values
# Out:
# array(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', ..., 'Zakarian, Mr. Mapriededer',
#        'Zakarian, Mr. Ortin', 'Zimmerman, Mr. Leo'], dtype=object)

# %%
names.index
# index da byb2a ely 3ala shemal>> ely hwa el label..... hatb2an aktar fel houses >> see down
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
mins = houses.min()
mins
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                   290
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
mins.index
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
houses.mean()
# Out:
# C:\Users\Hossam\AppData\Local\Temp\ipykernel_3472\686991280.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   houses.mean()
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788391e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# dtype: float64

# %%
houses.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %%
houses['price'].sum()
# Out:
# 11672925008.0

# %%
titanic.age.head(10)
# Out:
# 0        29
# 1    0.9167
# 2         2
# 3        30
# 4        25
# 5        48
# 6        63
# 7        39
# 8        53
# 9        71
# Name: age, dtype: object

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.title.tail(50)
# Out:
# 8757                 World Trade Center
# 8758             World's Busiest Cities
# 8759             World's Weirdest Homes
# 8760                   Would You Rather
# 8761                          Wrong No.
# 8762                    Wrong Side Raju
# 8763    WWII: Report from the Aleutians
# 8764                         Wyatt Earp
# 8765                                 XX
# 8766                                XXx
# 8767            XXX: State of the Union
# 8768                  Y Tu Mamá También
# 8769             Y.M.I.: Yeh Mera India
# 8770                            Yaadein
# 8771                   Yaara O Dildaara
# 8772              Yamla Pagla Deewana 2
# 8773                Yanda Kartavya Aahe
# 8774                          يوم الدين
# 8775                    Yeh Meri Family
# 8776                         Yellowbird
# 8777                          Yes or No
# 8778                        Yes or No 2
# 8779                      Yes or No 2.5
# ...

# %%
houses.describe(include = 'all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses['price'].describe()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
netflix['rating'].describe()
# Out:
# count      8803
# unique       17
# top       TV-MA
# freq       3207
# Name: rating, dtype: object

# %%
netflix.dtypes
# dtypes <- data types
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
titanic['name'].dtype
# Out:
# dtype('O')

# %%
pd.options.display.min_rows = 63
pd.options.display.max_rows = 64

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
# 7        3
# 8        3
# 9        3
# 10       3
# 11       2
# 12       3
# 13       3
# 14       5
# 15       4
# 16       3
# 17       4
# 18       2
# 19       3
# 20       4
# 21       3
# 22       5
# 23       2
# 24       3
# 25       3
# 26       3
# 27       3
# 28       3
# 29       4
# 30       3
#         ..
# 21582    3
# 21583    2
# 21584    3
# 21585    3
# 21586    2
# 21587    3
# 21588    2
# 21589    3
# 21590    4
# 21591    4
# 21592    3
# 21593    5
# 21594    4
# 21595    2
# 21596    5
# 21597    4
# 21598    4
# 21599    4
# 21600    5
# 21601    3
# 21602    3
# 21603    3
# 21604    3
# 21605    4
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix.rating.dtype
# Out:
# dtype('O')

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.rating.nunique()
# Out:
# 17

# %%
houses.zipcode.nunique()
# Out:
# 70

# %%
houses.zipcode.nunique()
# Out:
# 70

# %%
houses.zipcode
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
# 5        98053
# 6        98003
# 7        98198
# 8        98146
# 9        98038
# 10       98007
# 11       98115
# 12       98028
# 13       98074
# 14       98107
# 15       98126
# 16       98019
# 17       98103
# 18       98002
# 19       98003
# 20       98133
# 21       98040
# 22       98092
# 23       98030
# 24       98030
# 25       98002
# 26       98119
# 27       98112
# 28       98115
# 29       98052
# 30       98027
#          ...
# 21582    98117
# 21583    98102
# 21584    98116
# 21585    98042
# 21586    98107
# 21587    98125
# 21588    98117
# 21589    98038
# 21590    98074
# 21591    98178
# 21592    98103
# 21593    98056
# 21594    98042
# 21595    98103
# 21596    98059
# 21597    98040
# 21598    98001
# 21599    98053
# 21600    98004
# 21601    98125
# 21602    98010
# 21603    98065
# 21604    98144
# 21605    98056
# 21606    98136
# 21607    98116
# ...

# %%
houses.zipcode.unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
houses.zipcode.nunique()
# Out:
# 70

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
netflix.rating.nunique(dropna = False)
# Out:
# 18

# %%
netflix.rating.nunique(dropna = True)
# Out:
# 17

# %%
houses.price
# Out:
# 0         221900.0
# 1         538000.0
# 2         180000.0
# 3         604000.0
# 4         510000.0
# 5        1225000.0
# 6         257500.0
# 7         291850.0
# 8         229500.0
# 9         323000.0
# 10        662500.0
# 11        468000.0
# 12        310000.0
# 13        400000.0
# 14        530000.0
# 15        650000.0
# 16        395000.0
# 17        485000.0
# 18        189000.0
# 19        230000.0
# 20        385000.0
# 21       2000000.0
# 22        285000.0
# 23        252700.0
# 24        329000.0
# 25        233000.0
# 26        937000.0
# 27        667000.0
# 28        438000.0
# 29        719000.0
# 30        580500.0
#            ...
# 21582     490000.0
# 21583     399950.0
# 21584     380000.0
# 21585     270000.0
# 21586     505000.0
# 21587     385000.0
# 21588     414500.0
# 21589     347500.0
# 21590    1222500.0
# 21591     572000.0
# 21592     475000.0
# 21593    1088000.0
# 21594     350000.0
# 21595     520000.0
# 21596     679950.0
# ...

# %%
houses.price.nlargest(9)
# a3la 9
# Out:
# 7252    7700000.0
# 3914    7062500.0
# 9254    6885000.0
# 4411    5570000.0
# 1448    5350000.0
# 1315    5300000.0
# 1164    5110800.0
# 8092    4668000.0
# 2626    4500000.0
# Name: price, dtype: float64

# %%
houses.price.nsmallest(5)
# 2a2l 5
# Out:
# 1149     75000.0
# 15293    78000.0
# 465      80000.0
# 16198    81000.0
# 8274     82000.0
# Name: price, dtype: float64

# %%
titanic.pclass.nlargest(5)
# Out:
# 600    3
# 601    3
# 602    3
# 603    3
# 604    3
# Name: pclass, dtype: int64

# %%
titanic.pclass.nlargest(5,keep = 'all')
# da law homa repeated, size will be larger than n
# Out:
# 600     3
# 601     3
# 602     3
# 603     3
# 604     3
# 605     3
# 606     3
# 607     3
# 608     3
# 609     3
# 610     3
# 611     3
# 612     3
# 613     3
# 614     3
# 615     3
# 616     3
# 617     3
# 618     3
# 619     3
# 620     3
# 621     3
# 622     3
# 623     3
# 624     3
# 625     3
# 626     3
# 627     3
# 628     3
# 629     3
# 630     3
#        ..
# 1278    3
# 1279    3
# 1280    3
# 1281    3
# 1282    3
# 1283    3
# 1284    3
# 1285    3
# 1286    3
# 1287    3
# 1288    3
# 1289    3
# 1290    3
# 1291    3
# 1292    3
# 1293    3
# 1294    3
# 1295    3
# 1296    3
# 1297    3
# 1298    3
# 1299    3
# 1300    3
# 1301    3
# 1302    3
# 1303    3
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 709, dtype: int64

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
houses.nlargest(10,columns= ['price'])
# hatly dataframe for a3la 10 mn na7yet el price
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
houses.nlargest(10,columns  = ['bedrooms'])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nlargest(10,columns = ['bedrooms','bathrooms'])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses.nsmallest(10,['price'])
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
# 2141   1623049041  20140508T000000  82500.0         2       1.00          520
# 18468  7999600180  20140529T000000  83000.0         2       1.00          900
# 3767   1523049188  20150430T000000  84000.0         2       1.00          700
# 10253  2422049104  20140915T000000  85000.0         2       1.00          830
# 16714  1322049150  20150305T000000  85000.0         2       1.00          910
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
houses.shape
# Out:
# (21613, 21)

# %%
pd.options.display.min_rows
# Out:
# 63

# %%
pd.get_option("display.min_rows")
# Out:
# 63

# %%
pd.set_option('display.min_rows',20)

# %%
pd.get_option('display.min_rows')
# Out:
# 20

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# selecting more than a column
netflix[['rating','director']]
# Out:
#      rating                       director
# 0     PG-13                Kirsten Johnson
# 1     TV-MA                            NaN
# 2     TV-MA                Julien Leclercq
# 3     TV-MA                            NaN
# 4     TV-MA                            NaN
# 5     TV-MA                  Mike Flanagan
# 6        PG  Robert Cullen, José Luis Ucha
# 7     TV-MA                   Haile Gerima
# 8     TV-14                Andy Devonshire
# 9     PG-13                 Theodore Melfi
# ...     ...                            ...
# 8797  TV-Y7                            NaN
# 8798  TV-MA        Chandra Prakash Dwivedi
# 8799  TV-14                 Avadhoot Gupte
# 8800  TV-PG                            NaN
# 8801  TV-MA                Majid Al Ansari
# 8802      R                  David Fincher
# 8803  TV-Y7                            NaN
# 8804      R                Ruben Fleischer
# 8805     PG                   Peter Hewitt
# 8806  TV-14                    Mozez Singh
#
# ...

# %%
# selecting more than a column
netflix[['rating','director']].head(10)
# Out:
#   rating                       director
# 0  PG-13                Kirsten Johnson
# 1  TV-MA                            NaN
# 2  TV-MA                Julien Leclercq
# 3  TV-MA                            NaN
# 4  TV-MA                            NaN
# 5  TV-MA                  Mike Flanagan
# 6     PG  Robert Cullen, José Luis Ucha
# 7  TV-MA                   Haile Gerima
# 8  TV-14                Andy Devonshire
# 9  PG-13                 Theodore Melfi

# %%
netflix[['title','rating']].tail(10)
# Out:
#                    title rating
# 8797           Zak Storm  TV-Y7
# 8798            Zed Plus  TV-MA
# 8799               Zenda  TV-14
# 8800  Zindagi Gulzar Hai  TV-PG
# 8801             Zinzana  TV-MA
# 8802              Zodiac      R
# 8803         Zombie Dumb  TV-Y7
# 8804          Zombieland      R
# 8805                Zoom     PG
# 8806              Zubaan  TV-14

# %%
houses[['price','bedrooms','bathrooms']].describe()
# Out:
#               price      bedrooms     bathrooms
# count  2.161300e+04  21613.000000  21613.000000
# mean   5.400881e+05      3.370842      2.114757
# std    3.671272e+05      0.930062      0.770163
# min    7.500000e+04      0.000000      0.000000
# 25%    3.219500e+05      3.000000      1.750000
# 50%    4.500000e+05      3.000000      2.250000
# 75%    6.450000e+05      4.000000      2.500000
# max    7.700000e+06     33.000000      8.000000

# %%
cols = ['price','zipcode','sqft_lot']
houses[cols]
# Out:
#            price  zipcode  sqft_lot
# 0       221900.0    98178      5650
# 1       538000.0    98125      7242
# 2       180000.0    98028     10000
# 3       604000.0    98136      5000
# 4       510000.0    98074      8080
# 5      1225000.0    98053    101930
# 6       257500.0    98003      6819
# 7       291850.0    98198      9711
# 8       229500.0    98146      7470
# 9       323000.0    98038      6560
# ...          ...      ...       ...
# 21603   507250.0    98065      5536
# 21604   429000.0    98144      1126
# 21605   610685.0    98056      6023
# 21606  1007500.0    98136      7200
# 21607   475000.0    98116      1294
# 21608   360000.0    98103      1131
# 21609   400000.0    98146      5813
# 21610   402101.0    98144      1350
# 21611   400000.0    98027      2388
# 21612   325000.0    98144      1076
#
# [21613 rows x 3 columns]

# %%
houses['bedrooms']
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
# 7        3
# 8        3
# 9        3
#         ..
# 21603    3
# 21604    3
# 21605    4
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
netflix['rating']
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
# 5       TV-MA
# 6          PG
# 7       TV-MA
# 8       TV-14
# 9       PG-13
#         ...
# 8797    TV-Y7
# 8798    TV-MA
# 8799    TV-14
# 8800    TV-PG
# 8801    TV-MA
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
netflix['rating'].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
netflix['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix.rating.nunique()
# Out:
# 17

# %%
titanic.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
#          ...
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
netflix.director.value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
# Cathy Garcia-Molina               13
# Martin Scorsese                   12
# Youssef Chahine                   12
# Jay Chapman                       12
# Steven Spielberg                  11
#                                   ..
# Azazel Jacobs                      1
# Jung Ji-woo                        1
# Matt D'Avella                      1
# Parthiban                          1
# Scott McAboy                       1
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
netflix.director.value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
netflix.director.value_counts(ascending=True)
# Out:
# Kirsten Johnson                   1
# Evgeny Afineevsky                 1
# Kristina Goolsby, Ashley York     1
# Phil Joanou                       1
# Anthony Pierce                    1
# Jennifer Phang                    1
# Jill Bauer, Ronna Gradus          1
# Mike Fleiss                       1
# Aziz Ansari                       1
# David Sampliner                   1
#                                  ..
# Steven Spielberg                 11
# Jay Chapman                      12
# Youssef Chahine                  12
# Martin Scorsese                  12
# Cathy Garcia-Molina              13
# Jay Karas                        14
# Suhas Kadav                      16
# Marcus Raboy                     16
# Raúl Campos, Jan Suter           18
# Rajiv Chilaka                    19
# Name: director, Length: 4528, dtype: int64

# %%
houses.floors
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        2.0
# 7        1.0
# 8        1.0
# 9        2.0
#         ...
# 21603    2.0
# 21604    3.0
# 21605    2.0
# 21606    2.0
# 21607    2.0
# 21608    3.0
# 21609    2.0
# 21610    2.0
# 21611    2.0
# 21612    2.0
# Name: floors, Length: 21613, dtype: float64

# %%
houses['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %%
houses['floors'].value_counts().describe()
# Out:
# count        6.000000
# mean      3602.166667
# std       4651.294590
# min          8.000000
# 25%        274.000000
# 50%       1261.500000
# 75%       6658.250000
# max      10680.000000
# Name: floors, dtype: float64

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# ...

# %%
houses[['bedrooms','bathrooms']].value_counts()
# Out:
# bedrooms  bathrooms
# 4         2.50         2502
# 3         2.50         2357
#           1.75         1870
#           1.00         1780
# 2         1.00         1558
# 3         2.25         1082
#           2.00         1048
#           1.50          829
# 4         1.75          719
#           2.25          709
#                        ...
# 0         1.50            1
#           1.00            1
# 6         6.00            1
#           7.75            1
#           8.00            1
# 7         1.00            1
#           3.25            1
#           5.50            1
#           5.75            1
# 33        1.75            1
# Length: 144, dtype: int64

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
# 5        4
# 6        3
# 7        3
# 8        3
# 9        3
#         ..
# 21603    3
# 21604    3
# 21605    4
# 21606    4
# 21607    3
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses.bedrooms.plot()
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
houses.bedrooms.value_counts().plot(kind = 'bar')
""" 
bar: bar plot
box: box plot 
hist: histogram
pie : pie plot
scatter : scatter plot
"""
# Out:
# ' \nbar: bar plot\nbox: box plot \nhist: histogram\npie : pie plot\nscatter : scatter plot\n'

# %%
houses.bedrooms.value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='bedrooms'>

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic.survived.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
#          ...
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
titanic.sex.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
houses.nlargest(10,['bedrooms','bathrooms'])
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 16844  8823900290  20150317T000000  1400000.0         9       4.00
# 4235   2902200015  20150106T000000   700000.0         9       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# 8757          3000      4960     2.0           0     0  ...      7
# ...

# %%
houses[['bedrooms','bathrooms']].plot()
# el x-axis hwa el label 
# el y-axis hwa el freq
# Out:
# <AxesSubplot:>

# %%
df = houses[['bedrooms','bathrooms']]
df.plot(kind = 'scatter',x='bedrooms',y='bathrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses = houses[houses['bedrooms']<33]

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# ...           ...              ...        ...       ...        ...
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# ...
