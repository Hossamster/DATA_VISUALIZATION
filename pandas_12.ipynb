# %%
import pandas as pd

# %%
pd.to_datetime('2019-01-24')
# Out:
# Timestamp('2019-01-24 00:00:00')

# %%
pd.to_datetime('2015/04/23')
# Out:
# Timestamp('2015-04-23 00:00:00')

# %%
pd.to_datetime('December 21st 2016')
# Out:
# Timestamp('2016-12-21 00:00:00')

# %%
pd.to_datetime('December 31st 2010 4pm')
# Out:
# Timestamp('2010-12-31 16:00:00')

# %%
pd.to_datetime('Dec. 25 1990 12pm')
# Out:
# Timestamp('1990-12-25 12:00:00')

# %%
pd.to_datetime('3:55:32 Apr. 2nd 76')
# Out:
# Timestamp('1976-04-02 03:55:32')

# %%
dates = ['6:55:32 Jan. 24 00','4:32:12 Feb. 12 99','5:31:51 May. 11 87']

# %%
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2000-01-24 06:55:32', '1999-02-12 04:32:12',
#                '1987-05-11 05:31:51'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('10/11/12') # umbigous right ?
# Out:
# Timestamp('2012-10-11 00:00:00')

# %% [markdown]
# # It depends on where are u from !

# %%
pd.to_datetime('10/11/12',dayfirst=True) # dayfirst
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime('10/11/12',yearfirst=True,dayfirst=True) # dayfirst
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime('10/11/12',format = '%y/%d/%m')
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
meetings = ['Dec 11 2019 Meeting','Jan 3 2009 Meeting','Feb 24 2011 Meeting','Apr 21 1991 Meeting']

# %%
pd.to_datetime(meetings, format = '%b %d %Y Meeting')
# Out:
# DatetimeIndex(['2019-12-11', '2009-01-03', '2011-02-24', '1991-04-21'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # https://docs.python.org/3/library/datetime.html

# %%
ufos = pd.read_csv(r'D:\mygithub\data_visualization\data\nuforc_reports.csv')
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
pd.to_datetime(ufos['date_time'])
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos.info()
# didn't change
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
ufos['date'] = pd.to_datetime(ufos['date_time'])

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufos['date_time'] = pd.to_datetime(ufos['date_time'])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 8.7+ MB

# %%
ufos.drop(columns=['date'])
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos = pd.read_csv(r'D:\mygithub\data_visualization\data\nuforc_reports.csv',parse_dates=['date_time'])

# %%
ufos.info() # changed ...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87891 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84954 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos['date_time'].dt.year
# Out:
# 0        2019.0
# 1        2019.0
# 2           NaN
# 3        2019.0
# 4        2009.0
#           ...
# 88120    2019.0
# 88121    2019.0
# 88122    2019.0
# 88123    2019.0
# 88124    2019.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos['date_time'].dt.month
# Out:
# 0        12.0
# 1         3.0
# 2         NaN
# 3         4.0
# 4         3.0
#          ...
# 88120    10.0
# 88121    10.0
# 88122    10.0
# 88123    10.0
# 88124    10.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos['date_time'].dt.day
# Out:
# 0        12.0
# 1        22.0
# 2         NaN
# 3        17.0
# 4        15.0
#          ...
# 88120     2.0
# 88121     2.0
# 88122     2.0
# 88123     2.0
# 88124     2.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos['date_time'].dt.year.value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
ufos['date_time'].dt.month.value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
ufos['date_time'].dt.hour.value_counts().head(10)
# Out:
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# Name: date_time, dtype: int64

# %%
ufos['date_time'].dt.dayofweek
# Out:
# 0        3.0
# 1        4.0
# 2        NaN
# 3        2.0
# 4        6.0
#         ...
# 88120    2.0
# 88121    2.0
# 88122    2.0
# 88123    2.0
# 88124    2.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos['date_time'].dt.dayofweek.value_counts()
# Out:
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: date_time, dtype: int64

# %% [markdown]
# # <> >= <= != ==
# # year only ....

# %%
ufos[ufos['date_time'] < '1980']
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos[ufos['date_time'] >= '2019/12/23']
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufos['date_time'].dt.date
# Out:
# 0        2019-12-12
# 1        2019-03-22
# 2               NaT
# 3        2019-04-17
# 4        2009-03-15
#             ...
# 88120    2019-10-02
# 88121    2019-10-02
# 88122    2019-10-02
# 88123    2019-10-02
# 88124    2019-10-02
# Name: date_time, Length: 88125, dtype: object

# %%
ufos['date_time'].dt.time
# Out:
# 0        18:43:00
# 1        18:30:00
# 2             NaT
# 3        02:00:00
# 4        18:00:00
#            ...
# 88120    20:00:00
# 88121    20:00:00
# 88122    20:03:00
# 88123    22:00:00
# 88124    22:00:00
# Name: date_time, Length: 88125, dtype: object

# %%
ufos[ufos['date_time'].dt.hour == 2.0]
# Out:
#                                                  summary               city  \
# 3      I was driving towards the intersection of fall...             Ottawa
# 14     Bright Circle of Light followed me from Oskalo...        Centerville
# 148                                Strange Vibrations...          Indianola
# 153    red ball ufo following small plane in tracy, c...              Tracy
# 181    Silver disk flies through sky making zigzaggin...          Beaverton
# ...                                                  ...                ...
# 87975  Massive triangle at very low altitude and low ...       Hawkinsville
# 88026  Triangle on fire traveling through the night s...  Panama City Beach
# 88027  At first It looked like a drone but it was mov...        Panama City
# 88056                                     MADAR Node 157          Pensacola
# 88097                             Hovering band of light           Columbia
#
# ...

# %%
ufos[ufos['date_time'].between('1988','1989')].sort_values('date_time')
# Out:
#                                                  summary             city  \
# 4128   fast moving Triangle with no sound and orange ...          Roselle
# 8389   Gigantic circular object hovering, and then wi...           Kenner
# 2071   Broad daylight gold colored flying object abou...  New Britain Twp
# 33511  A dull yellow light, low off the ground and no...    Williamsfield
# 16295  8 gliding craft in formation with a 9th "quant...        Cambridge
# ...                                                  ...              ...
# 82524  Very bright light moving from South to North, ...        Dry Creek
# 21938  large saucer shaped object with many colored l...           Dexter
# 8808   Black huge triangle craft with chevron shape o...         Stockton
# 4363   saw 5 objects doing amazing manuevers for 20 m...       Alamogordo
# 61675  Hi 3 of us were out joy riding in our small ky...           Aurora
#
#       state           date_time     shape        duration  \
# ...

# %%
ufos.insert(0,'new_time',ufos['date_time'])

# %%
ufos
# Out:
#                  new_time                                            summary  \
# 0     2019-12-12 18:43:00  My wife was driving southeast on a fairly popu...
# 1     2019-03-22 18:30:00  I think that I may caught a UFO on the NBC Nig...
# 2                     NaT  I woke up late in the afternoon 3:30-4pm. I we...
# 3     2019-04-17 02:00:00  I was driving towards the intersection of fall...
# 4     2009-03-15 18:00:00  In Peoria Arizona, I saw a cigar shaped craft ...
# ...                   ...                                                ...
# 88120 2019-10-02 20:00:00  4 lights in formation over Tempe appear while ...
# 88121 2019-10-02 20:00:00  2 bright star like lights in the NNW skys,  ((...
# 88122 2019-10-02 20:03:00  I just witnessed a ‘Phoenix Lights’ type of fo...
# 88123 2019-10-02 22:00:00  Witnessed an orange, slow moving light. Was lo...
# 88124 2019-10-02 22:00:00  Glowing lights in formation  just south of San...
#
# ...

# %%
index_values = ufos.index.values

# %%
ufos.insert(1,'copy_index',index_values)

# %%
ufos.set_index('new_time',inplace = True)

# %%
ufos
# Out:
#                      copy_index  \
# new_time
# 2019-12-12 18:43:00           0
# 2019-03-22 18:30:00           1
# NaT                           2
# 2019-04-17 02:00:00           3
# 2009-03-15 18:00:00           4
# ...                         ...
# 2019-10-02 20:00:00       88120
# 2019-10-02 20:00:00       88121
# 2019-10-02 20:03:00       88122
# 2019-10-02 22:00:00       88123
# 2019-10-02 22:00:00       88124
#
#                                                                summary  \
# new_time
# 2019-12-12 18:43:00  My wife was driving southeast on a fairly popu...
# 2019-03-22 18:30:00  I think that I may caught a UFO on the NBC Nig...
# NaT                  I woke up late in the afternoon 3:30-4pm. I we...
# 2019-04-17 02:00:00  I was driving towards the intersection of fall...
# 2009-03-15 18:00:00  In Peoria Arizona, I saw a cigar shaped craft ...
# ...                                                                ...
# ...

# %%
ufos.between_time('18:43','22:30')
# Out:
#                      copy_index  \
# new_time
# 2019-12-12 18:43:00           0
# 2019-04-02 20:25:00           5
# 1973-07-14 22:00:00           8
# 2019-06-06 19:00:00           9
# 2019-06-18 21:00:00          10
# ...                         ...
# 2019-10-02 20:00:00       88120
# 2019-10-02 20:00:00       88121
# 2019-10-02 20:03:00       88122
# 2019-10-02 22:00:00       88123
# 2019-10-02 22:00:00       88124
#
#                                                                summary  \
# new_time
# 2019-12-12 18:43:00  My wife was driving southeast on a fairly popu...
# 2019-04-02 20:25:00  The object has flashing lights that are green,...
# 1973-07-14 22:00:00  Ufos report in Irving Texas at 2200 hrs. On or...
# 2019-06-06 19:00:00  Group of lights formation sweeping thru a nigh...
# 2019-06-18 21:00:00  Metal orb of wires that was seen through a tel...
# ...                                                                ...
# ...

# %%
df =ufos.between_time('18:43','22:30')

# %%
df
# Out:
#                      copy_index  \
# new_time
# 2019-12-12 18:43:00           0
# 2019-04-02 20:25:00           5
# 1973-07-14 22:00:00           8
# 2019-06-06 19:00:00           9
# 2019-06-18 21:00:00          10
# ...                         ...
# 2019-10-02 20:00:00       88120
# 2019-10-02 20:00:00       88121
# 2019-10-02 20:03:00       88122
# 2019-10-02 22:00:00       88123
# 2019-10-02 22:00:00       88124
#
#                                                                summary  \
# new_time
# 2019-12-12 18:43:00  My wife was driving southeast on a fairly popu...
# 2019-04-02 20:25:00  The object has flashing lights that are green,...
# 1973-07-14 22:00:00  Ufos report in Irving Texas at 2200 hrs. On or...
# 2019-06-06 19:00:00  Group of lights formation sweeping thru a nigh...
# 2019-06-18 21:00:00  Metal orb of wires that was seen through a tel...
# ...                                                                ...
# ...

# %%
ufos.set_index('copy_index')
# Out:
#                                                       summary            city  \
# copy_index
# 0           My wife was driving southeast on a fairly popu...         Chester
# 1           I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2           I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3           I was driving towards the intersection of fall...          Ottawa
# 4           In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                       ...             ...
# 88120       4 lights in formation over Tempe appear while ...           Tempe
# 88121       2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122       I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123       Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124       Glowing lights in formation  just south of San...    Marin County
#
# ...

# %%
ufos['date_time'].value_counts()
# Out:
# 2015-11-07 18:00:00    104
# 2014-07-04 22:00:00     46
# 2010-07-04 22:00:00     37
# 2012-07-04 22:00:00     34
# 2015-07-04 22:00:00     27
#                       ...
# 2011-07-23 23:20:00      1
# 2011-07-23 23:47:00      1
# 2011-07-24 00:00:00      1
# 2011-07-24 00:02:00      1
# 2019-12-12 18:43:00      1
# Name: date_time, Length: 73122, dtype: int64

# %%
ufos['date_time'].dt.date.value_counts()
# Out:
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
#              ...
# 1980-09-12      1
# 1988-06-13      1
# 1981-07-29      1
# 2004-07-04      1
# 2003-09-07      1
# Name: date_time, Length: 8351, dtype: int64

# %%
recent_sightings = ufos[ufos['date_time'].dt.year >= 2018]
recent_sightings
# Out:
#                  new_time                                            summary  \
# 0     2019-12-12 18:43:00  My wife was driving southeast on a fairly popu...
# 1     2019-03-22 18:30:00  I think that I may caught a UFO on the NBC Nig...
# 3     2019-04-17 02:00:00  I was driving towards the intersection of fall...
# 5     2019-04-02 20:25:00  The object has flashing lights that are green,...
# 6     2019-05-01 11:00:00  Description is the same as Washington DC event...
# ...                   ...                                                ...
# 88120 2019-10-02 20:00:00  4 lights in formation over Tempe appear while ...
# 88121 2019-10-02 20:00:00  2 bright star like lights in the NNW skys,  ((...
# 88122 2019-10-02 20:03:00  I just witnessed a ‘Phoenix Lights’ type of fo...
# 88123 2019-10-02 22:00:00  Witnessed an orange, slow moving light. Was lo...
# 88124 2019-10-02 22:00:00  Glowing lights in formation  just south of San...
#
# ...

# %%
recent_sightings['date_time'].value_counts()
# Out:
# 2019-11-11 19:00:00    16
# 2018-07-04 22:00:00    12
# 2019-11-11 18:00:00    12
# 2019-07-04 22:00:00    10
# 2018-10-07 19:30:00     9
#                        ..
# 2018-03-29 19:05:00     1
# 2018-03-29 11:00:00     1
# 2018-04-11 20:00:00     1
# 2018-04-11 12:05:00     1
# 2018-08-24 23:15:00     1
# Name: date_time, Length: 7950, dtype: int64

# %%
ufos[ufos['date_time'].between('2019-05-24','2019-05-26')]
# Out:
#                 new_time                                            summary  \
# 1913 2019-05-24 00:00:00  Were looking up at the stars and a string of w...
# 1914 2019-05-24 00:02:00  May 24th at approximately 0002 hours I witness...
# 1915 2019-05-24 00:05:00  30 white orbs.  ((NUFORC Note:  Satellites fro...
# 1916 2019-05-24 00:14:00  seen a rip in the night sky.it looks like a br...
# 1917 2019-05-24 00:16:00  It was somewhat a slow moving blurry light obj...
# ...                  ...                                                ...
# 2521 2019-05-26 00:00:00           Intense Bright Flashes for Four Hours...
# 2581 2019-05-26 00:00:00  We were outside, 11:54pm, saw 4 lights moving ...
# 2582 2019-05-26 00:00:00  Reported seeing a triangle of lights, moving a...
# 2583 2019-05-26 00:00:00  Formation of lights grows larger and passes ab...
# 2584 2019-05-26 00:00:00  Huge 3 light UFO in night sky,  5/26/19.  ((an...
#
# ...

# %%
ufos['posted'] = pd.to_datetime(ufos['posted'])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   new_time        86938 non-null  datetime64[ns]
#  1   summary         88095 non-null  object
#  2   city            87891 non-null  object
#  3   state           82890 non-null  object
#  4   date_time       86938 non-null  datetime64[ns]
#  5   shape           85627 non-null  object
#  6   duration        84954 non-null  object
#  7   stats           88088 non-null  object
#  8   report_link     88125 non-null  object
#  9   text            88070 non-null  object
#  10  posted          86938 non-null  datetime64[ns]
#  11  city_latitude   72013 non-null  float64
#  12  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](3), float64(2), object(8)
# memory usage: 8.7+ MB

# %%
ufos['time_before_reported'] = ufos['posted'] - ufos['date_time']

# %%
ufos['time_before_reported']
# Out:
# 0          9 days 05:17:00
# 1          6 days 05:30:00
# 2                      NaT
# 3          0 days 22:00:00
# 4       3685 days 06:00:00
#                ...
# 88120      1 days 04:00:00
# 88121      1 days 04:00:00
# 88122      1 days 03:57:00
# 88123      1 days 02:00:00
# 88124      1 days 02:00:00
# Name: time_before_reported, Length: 88125, dtype: timedelta64[ns]

# %%
longest_wait = ufos.sort_values('time_before_reported',ascending = False).head(10)

# %%
longest_wait
# Out:
#                  new_time                                            summary  \
# 86762 1969-06-01 00:00:00  An incomplete report given on behalf of anothe...
# 87145 1969-07-04 01:30:00                      Strange globe sighting--1969.
# 721   1969-07-01 21:00:00  It was July 1969 on a clear summer evening in ...
# 1576  1969-06-30 00:00:00  1969 olive branch Mississippi large round ligh...
# 1580  1969-08-15 16:00:00  Six bright lights in &quot;V&quot; formation s...
# 84984 1969-06-15 01:00:00  Possible abduction in Colorado in 1969.  ((ano...
# 83965 1970-07-15 00:00:00  Mysterious light in the sky over Southeren Cal...
# 722   1970-06-30 00:00:00  Object blended with dark, bright light as if d...
# 723   1970-08-15 02:00:00  The dark object was within 15 feet of me, not ...
# 1301  1970-06-30 18:00:00  Elsmere Delaware Linden ave Park Large round n...
#
#                city state           date_time      shape       duration  \
# ...

# %%
longest_wait['time_before_reported'] .dt.days / 365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_before_reported, dtype: float64

# %%
ufos['days_before_reporting'] = ufos['time_before_reported'].dt.days / 365

# %%
charts = pd.read_csv(r'D:\mygithub\data_visualization\data\billboard_charts.csv',parse_dates=['date'])

# %%
charts
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
charts['artist'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
charts.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
number_1s = charts['rank'] == 1
charts[number_1s]['artist'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
charts[number_1s]['song'].value_counts()
# Out:
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: song, Length: 1104, dtype: int64

# %%
charts[charts['song'] == 'Old Town Road']['rank'].plot()
# Out:
# <AxesSubplot:>

# %%
p = charts[charts['song'] == 'Old Town Road'].set_index('date')['rank'].plot()
p.invert_yaxis()
