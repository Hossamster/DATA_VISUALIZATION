# %%
import pandas as pd 
countries = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\world-happiness-report-2021.csv',index_col = 0)
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {'Regional indicator':'regional_indicator','Ladder score':'ladder_score'}
countries.rename(columns = mapper,inplace = True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {'Finland' : 'finlaaand', 'Denmark':'denmaaark','Iceland':'icelaaand'}
countries.rename(index = mapper,inplace = True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finlaaand         Western Europe         7.842
# denmaaark         Western Europe         7.620
# Switzerland       Western Europe         7.571
# icelaaand         Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finlaaand                              0.032         7.904         7.780
# denmaaark                              0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\titanic.csv')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['sex'].replace('female','F',inplace = True)

# %%
titanic['sex'].replace('F','female',inplace = True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['sibsp'].replace([0,1],['False','True'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sibsp, Length: 1309, dtype: object

# %%
titanic['sex'].replace(['female','male'],['F','M'],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic['age'].replace(['?'],[None]).value_counts(dropna =False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
titanic['age'].replace(['?'],[None],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic['age'].value_counts(dropna = False)
# Out:
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: age, Length: 99, dtype: int64

# %%
countries.loc[['Brazil','Egypt'],['Healthy life expectancy','ladder_score']]
# Out:
#               Healthy life expectancy  ladder_score
# Country name
# Brazil                         66.601         6.330
# Egypt                          61.998         4.283

# %%
countries.rename(index = {'finlaaand':'Finland','icelaaand':'Iceland'},inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# denmaaark         Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# denmaaark                              0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc[['Denmark','Sweden','Norway'],['regional_indicator']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Hossam\Desktop\data visualiztion\pandas_10.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hossam/Desktop/data%20visualiztion/pandas_10.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> countries.loc[['Denmark','Sweden','Norway'],['regional_indicator']]
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# ...

# %%
countries.loc[['Denmark','Sweden','Norway'],['regional_indicator']] = 'Scandinavia'

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark              Scandinavia         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc['Finland'] = "LOL"

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                      LOL          LOL                            LOL
# Denmark              Scandinavia         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
countries.loc['Finland',['upperwhisker','lowerwhisker']] = "Meow"

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                      LOL          LOL                            LOL
# Denmark              Scandinavia         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway']]
# Out:
#              regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                     LOL          LOL                            LOL
# Denmark             Scandinavia         7.62                          0.035
# Iceland          Western Europe        7.554                          0.059
# Sweden              Scandinavia        7.363                          0.036
# Norway              Scandinavia        7.392                          0.035
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# Finland              Meow         Meow                   LOL            LOL
# Denmark             7.687        7.552                10.933          0.954
# Iceland              7.67        7.438                10.878          0.983
# Sweden              7.433        7.293                10.867          0.934
# Norway              7.462        7.323                11.053          0.954
#
# ...

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','isCold']] ='DOGS!!!'

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                  DOGS!!!          LOL                            LOL
# Denmark                  DOGS!!!         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland                  DOGS!!!        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
countries.loc[['Finland','Denmark','Iceland','Sweden','Norway'],['regional_indicator','isCold']] =['DOGS!!!','yes']

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# Finland                  DOGS!!!          LOL                            LOL
# Denmark                  DOGS!!!         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland                  DOGS!!!        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
houses = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\kc_house_data.csv')
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
many_rooms = houses['bedrooms'] >= 10

# %%
houses.loc[many_rooms,['bedrooms']] = 'TOO MANY!!!'

# %%
houses[many_rooms]
# Out:
#                id             date      price     bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  TOO MANY!!!       3.00
# 13314   627300145  20140814T000000  1148000.0  TOO MANY!!!       5.25
# 15161  5566100170  20141029T000000   650000.0  TOO MANY!!!       2.00
# 15870  2402100895  20140625T000000   640000.0  TOO MANY!!!       1.75
# 19254  8812401450  20141229T000000   660000.0  TOO MANY!!!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade sqft_above  \
# 8757          3000      4960     2.0           0     0  ...      7       2400
# 13314         4590     10920     1.0           0     2  ...      9       2500
# 15161         3610     11914     2.0           0     0  ...      7       3010
# 15870         1620      6000     1.0           0     0  ...      7       1040
# 19254         2920      3745     2.0           0     0  ...      7       1860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
high_quality = houses['price'] >= 500000
great_views = houses['view'] == 4
houses[high_quality & great_views]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 21     2524049179  20140826T000000  2000000.0        3       2.75
# 58     7922800400  20140827T000000   951000.0        5       3.25
# 230    8096000060  20150413T000000   655000.0        2       1.75
# 246    2025069065  20140929T000000  2400000.0        4       2.50
# 300    3225069065  20140624T000000  3075000.0        4       5.00
# ...           ...              ...        ...      ...        ...
# 20767  8043700105  20150417T000000  2300000.0        4       4.00
# 20923  7852070210  20140527T000000  1149000.0        4       3.00
# 21050  2424059170  20150219T000000   900000.0        5       6.00
# 21201   518500460  20141008T000000  2230000.0        3       3.50
# 21576  9253900271  20150107T000000  3567000.0        5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade sqft_above  \
# 21            3050     44867     1.0           0     4  ...      9       2330
# ...

# %%
houses['luxury'] = 'normal'

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
houses.loc[high_quality & great_views,['luxury']]  = 'ultra'

# %%
houses[high_quality & great_views]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 21     2524049179  20140826T000000  2000000.0        3       2.75
# 58     7922800400  20140827T000000   951000.0        5       3.25
# 230    8096000060  20150413T000000   655000.0        2       1.75
# 246    2025069065  20140929T000000  2400000.0        4       2.50
# 300    3225069065  20140624T000000  3075000.0        4       5.00
# ...           ...              ...        ...      ...        ...
# 20767  8043700105  20150417T000000  2300000.0        4       4.00
# 20923  7852070210  20140527T000000  1149000.0        4       3.00
# 21050  2424059170  20150219T000000   900000.0        5       6.00
# 21201   518500460  20141008T000000  2230000.0        3       3.50
# 21576  9253900271  20150107T000000  3567000.0        5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 21            3050     44867     1.0           0     4  ...        2330
# ...
