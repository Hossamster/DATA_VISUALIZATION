# %%
import pandas as pd

# %%
houses = pd.read_csv(r'D:\mygithub\data_visualization\data\kc_house_data.csv')
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.bedrooms.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Behind the scenes
# ### pandas calls some functions from matplotlib to plot

# %% [markdown]
# <body>
#
# <h4><p style="color:Tomato;">Why use Matplotlib ?</p></h4>
#
# </body>

# %% [markdown]
# <h4><p style= "color:MediumSeaGreen" >There are plots that u may want to do or customizations functionality that matplotlib has that pandas doesn't support.
# </p></h4>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([2,4,6,8])
# [2,4,6,8],[0,1,2,3] that's done behind the scenes...

# %%
plt.plot([1,4,2,6,9,2,3,1,8])

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]

# %%
plt.plot(ages,salaries)
plt.show()

# %% [markdown]
# ## preferable to write >> plt.show()

# %%
import numpy as np

# %%
nums = np.arange(5)

# %%
nums
# Out:
# array([0, 1, 2, 3, 4])

# %%
nums * 2
# Out:
# array([0, 2, 4, 6, 8])

# %%
plt.plot(nums,nums)
plt.plot(nums,nums**2)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.plot(nums,nums**2)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums,nums**2)
plt.figure()
plt.plot(nums,nums**3)
plt.show()

# %% [markdown]
# ### figsize to control the size of the figure
# ### dpi is to control the number of pixels per inch

# %%
plt.figure(figsize =(3,4) )
plt.plot(nums,nums)
plt.figure(figsize =(3,4), dpi = 150)
plt.plot(nums,nums**2)
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.plot(nums,nums**3)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.figure()
plt.plot(nums,nums)
plt.plot(nums,nums**2)
plt.plot(nums,nums**3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\mygithub\data_visualization\pandas_13.ipynb Cell 31 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_13.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> plt.figure()
#       <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_13.ipynb#X42sZmlsZQ%3D%3D?line=1'>2</a> plt.plot(nums,nums)
#       <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_13.ipynb#X42sZmlsZQ%3D%3D?line=2'>3</a> plt.plot(nums,nums**2)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### LOOKS different !!

# %%
plt.style.use('seaborn')

# %%
plt.figure()
plt.plot(nums,nums)
plt.plot(nums,nums**2)
plt.plot(nums,nums**3)

# %%
plt.style.use('Solarize_Light2')

# %%
plt.figure()
plt.plot(nums,nums)

# %%
plt.plot(nums,nums**2)
plt.plot(nums,nums**3)

# %%
plt.plot(nums,nums,color = 'blue',linewidth = 5)
plt.plot(nums,nums**2,color = 'orange',linewidth = 4)
plt.plot(nums,nums**3,c = '#0984e3',linewidth = 7)

# %%
plt.plot(nums,nums,color = 'blue',linewidth = 5 , linestyle = ':')
plt.plot(nums,nums**2,color = 'orange',linewidth = 4,linestyle = '--')
plt.plot(nums,nums**3,c = '#0984e3',linewidth = 7,linestyle = '-.')

# %%
plt.plot(nums,nums,color = 'blue',linewidth = 0.1,marker ='*',markersize = 20,markerfacecolor = 'red')

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.figure()
plt.plot(ages,salaries,c = 'red')
plt.title('company salaries')
plt.figure()
plt.title('linear line' )
plt.plot(nums,nums,c='blue',linestyle = '--')
plt.show()

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.figure()
plt.plot(ages,salaries,c = 'red')
plt.title('company salaries',loc = 'left')
plt.figure()
plt.title('linear line' , loc = 'right')
plt.plot(nums,nums,c='blue',linestyle = '--')
plt.show()

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.figure()
plt.plot(ages,salaries,c = 'red')
plt.title('company salaries' , fontsize = 24,fontstyle = 'italic',color = 'blue')
plt.xlabel('ages',labelpad = 10 , fontsize= 20)
plt.ylabel('salaries',fontsize = 20,labelpad = 40,rotation = 'horizontal')
plt.show()

# %%
plt.xticks([10,20,30,40,50])
# Out:
# ([<matplotlib.axis.XTick at 0x17f2de63dc0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.figure(figsize = (5,5))
plt.plot(ages,salaries,c = 'red')
plt.title('company salaries' , fontsize = 24)
plt.xlabel('ages' , fontsize= 20,color = 'blue')
plt.ylabel('salaries',fontsize = 20,color = 'blue')
plt.xticks(ticks = [20,25,30,35,40,45])
plt.yticks(ticks = [60000,80000,100000,120000,140000],labels = ['60k','80k','100k','120k','140k'])
plt.show()

# %%
salaries = [55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages,salaries,c = 'red')
plt.xlim(15,50)
plt.ylim(50000,160000)
# Out:
# (50000.0, 160000.0)

# %% [markdown]
# <h4><p style = "color:red">To do label, u must use the legend method</p></h4>

# %%
plt.figure(figsize = (8,8))
plt.plot(nums,color = 'teal',label = 'x')
plt.plot(nums**2,color = 'olive',label = 'x squared')
plt.plot(nums**3,color = 'purple',label = 'x cubed')
plt.legend()

# %%
plt.figure(figsize = (8,8))
plt.plot(nums,color = 'teal',label = 'x')
plt.plot(nums**2,color = 'olive',label = 'x squared')
plt.plot(nums**3,color = 'purple',label = 'x cubed')
plt.legend(loc = 'center left',frameon = True,shadow = True,title = 'bos hena 3ashan tefham',labelcolor = 'blue',facecolor = 'green')

# %%
plt.figure(figsize = (8,8),frameon = False)
plt.plot(nums, c= 'green' , label = 'x')
plt.plot(nums**2 , c = 'blue',label ='x squared')
plt.plot(nums**3,color = 'black',label  = 'x cubed')
mylegend = plt.legend(labelcolor='linecolor',loc = 'upper center',frameon = True,shadow = True,facecolor = 'white',title = 'shof kda',edgecolor ='green',title_fontsize = 27)
plt.setp(mylegend.get_title(),color = 'green')
# plt.setp(mylegend.get_texts(),color = 'purple')
plt.show()

# %%
plt.figure(figsize = (8,8),frameon = False)
plt.plot(nums,c = 'green',label = 'x')
plt.plot(nums**2,c = 'red' , label = 'x squared')
plt.plot(nums**3 , c = 'blue',label = 'x cubed')
mylegend = plt.legend(title = 'bos hena',loc = 'upper center',shadow = True,frameon = True,facecolor = 'yellow',labelcolor = 'linecolor')
plt.setp(mylegend.get_title(),color = 'purple')
plt.setp(mylegend.get_texts(),color= 'red')
plt.xlabel('time',fontsize = 15)
plt.ylabel('distance',fontsize = 15 , fontstyle = 'italic')
plt.title('Hossam',c = 'Green',fontsize = 20,fontname="arial")
plt.show()

# %% [markdown]
# # Going to >> Exercise Time

# %% [markdown]
# # Bar Plots

# %%
plants = ['Spanish','Turnip','Rhubarb','Broccoli','Kale']
died = [10,25,5,30,21]
germinated = [74,88,56,69,59]

# %%
plt.figure(figsize = (6,6))
plt.bar(plants,germinated,color = 'green',label = 'Died',width = 0.6)
plt.title('Germination rates')
plt.ylabel('Number of Seeldings')
plt.legend(loc = 'upper right')

# %%
plt.figure(figsize = (6,6))
plt.bar(plants,died,width = 0.5)
plt.ylabel('Number of Dead Seedlings',labelpad = 10,color ='black',fontsize = 15)
plt.title('Failure Rates')
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.bar(plants,died,width = 0.5,color = '#ff7675')
plt.bar(plants,germinated,width = 0.4,color = '#00cec9',align ='edge')
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.bar(plants,died,color = '#ff7675',bottom = germinated ,label = 'Failed Seedlings')
plt.bar(plants,germinated,color = '#00cec9',label = 'Germinated Seedlings')
plt.legend()
plt.title('Greenhouse Seedlings')
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.barh(plants,died,color = '#ff7675')
# Out:
# <BarContainer object of 5 artists>

# %%
nums = np.random.randn(100)

# %%
plt.hist(nums)
# Out:
# (array([ 5.,  3.,  7., 11., 18., 18., 13., 13.,  6.,  6.]),
#  array([-2.1608372 , -1.73616015, -1.31148311, -0.88680606, -0.46212902,
#         -0.03745198,  0.38722507,  0.81190211,  1.23657916,  1.6612562 ,
#          2.08593324]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nums,bins = 20,color = 'olive')
# Out:
# (array([ 2.,  3.,  1.,  2.,  3.,  4.,  8.,  3.,  8., 10., 11.,  7.,  5.,
#          8.,  5.,  8.,  3.,  3.,  3.,  3.]),
#  array([-2.1608372 , -1.94849868, -1.73616015, -1.52382163, -1.31148311,
#         -1.09914459, -0.88680606, -0.67446754, -0.46212902, -0.2497905 ,
#         -0.03745198,  0.17488655,  0.38722507,  0.59956359,  0.81190211,
#          1.02424063,  1.23657916,  1.44891768,  1.6612562 ,  1.87359472,
#          2.08593324]),
#  <BarContainer object of 20 artists>)

# %%
titanic = pd.read_csv(r'D:\mygithub\data_visualization\data\titanic.csv')
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic['age'] = pd.to_numeric(titanic['age'],errors= 'coerce')

# %%
titanic['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic['age'].value_counts()
# Out:
# 24.0000    47
# 22.0000    43
# 21.0000    41
# 30.0000    40
# 18.0000    39
#            ..
# 0.3333      1
# 22.5000     1
# 70.5000     1
# 0.6667      1
# 26.5000     1
# Name: age, Length: 98, dtype: int64

# %%
plt.hist(titanic['age'])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic['pclass']  == 1]['age']

# %%
plt.hist(first_class)
# Out:
# (array([ 4.,  7., 42., 46., 56., 50., 44., 27.,  6.,  2.]),
#  array([ 0.9167 ,  8.82503, 16.73336, 24.64169, 32.55002, 40.45835,
#         48.36668, 56.27501, 64.18334, 72.09167, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
second_class = titanic[titanic['pclass'] == 2]['age']

# %%
plt.hist(second_class)
# Out:
# (array([18.,  9., 36., 67., 59., 32., 15., 13., 10.,  2.]),
#  array([ 0.6667 ,  7.60003, 14.53336, 21.46669, 28.40002, 35.33335,
#         42.26668, 49.20001, 56.13334, 63.06667, 70.     ]),
#  <BarContainer object of 10 artists>)

# %%
third_class = titanic[titanic['pclass'] == 3]['age']

# %%
plt.figure()
plt.hist(first_class , label = 'First Class')
plt.hist(second_class,label = 'Second Class', color = 'red')
plt.hist(third_class , label = 'Third Class')
plt.legend()
plt.show()

# %%
plt.figure()
plt.hist(first_class , label = 'First Class',color = 'blue',alpha = 0.8)
plt.hist(second_class,label = 'Second Class', color = 'red',alpha = 0.8)
plt.hist(third_class , label = 'Third Class',color = 'green',alpha = 0.8)
plt.legend()
plt.show()

# %% [markdown]
# ### Scatter plots

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7, 42.8,43.1,45.8,50.8,58.9]

# %%
plt.scatter(heights,f_weights,color = 'purple',marker = '*',label = 'Female')
plt.scatter(heights,m_weights,color = 'red',marker = 'X',label = 'Male')
plt.xlabel('Heights (cm)')
plt.ylabel('Weights (kg)')
mylegend = plt.legend(shadow = True,frameon = True,facecolor = 'yellow',title = 'bos hena welnabi',loc = 'upper left')
plt.setp(mylegend.get_title(),color = '#00b894')
plt.setp(mylegend.get_texts()[0],color = '#00b894')
plt.show()

# %%
countries = ["Turkey", "Potatoes", "Pumpkin Pie", "Stuffing"]
prices = [25.99,3.24,9.50, 6.99]

# %%
plt.pie(prices,labels = countries,autopct='%1.1f%%',shadow = True,explode = (0,0,0.1,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x17f3f2f14e0>,
# ...
#  [Text(-0.23476164907796612, 1.0746566745347996, 'Turkey'),
#   Text(-0.873837836440518, -0.668137287991738, 'Potatoes'),
#   Text(-0.051107835699375104, -1.1989111681563926, 'Pumpkin Pie'),
#   Text(0.9755372148905609, -0.5082589323991933, 'Stuffing')],
#  [Text(-0.1280518085879815, 0.5861763679280724, '56.8%'),
#   Text(-0.47663881987664614, -0.3644385207227661, '7.1%'),
#   Text(-0.029812904157968806, -0.6993648480912289, '20.8%'),
#   Text(0.5321112081221241, -0.2772321449450145, '15.3%')])

# %% [markdown]
# # Subplots

# %%
nums = np.arange(5)

# %%
plt.figure(figsize =(10,4))
plt.suptitle('Comparison',fontsize = 30)
plt.subplot(1,3,1)
plt.title("X")
plt.plot(nums,nums)
plt.subplot(1,3,2)
plt.title('X squared')
plt.plot(nums,nums**2,color = 'red')
plt.subplot(1,3,3)
plt.title('X cubed')
plt.plot(nums,nums**3,color = 'green')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize =(4,10))
plt.suptitle('Comparison',fontsize = 30)

plt.subplot(3,1,1)
plt.title("X")
plt.plot(nums,nums)

plt.subplot(3,1,2)
plt.title('X squared')
plt.plot(nums,nums**2,color = 'red')

plt.subplot(3,1,3)
plt.title('X cubed')
plt.plot(nums,nums**3,color = 'green')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (8,8))
plt.suptitle('2 * 2 ')
plt.subplot(2,2,1)
plt.title('X')
plt.plot(nums,nums,)

plt.subplot(2,2,2)
plt.title('X squared')
plt.plot(nums,nums**2,)

plt.subplot(2,2,3)
plt.title('X squared')
plt.plot(nums,nums**3,)

plt.subplot(2,2,4)
plt.title('X squared')
plt.plot(nums,nums**4,)
plt.tight_layout()

# %%
first_class = titanic[titanic['pclass'] == 1]['age']
second_class = titanic[titanic['pclass'] == 2]['age']
third_class = titanic[titanic['pclass'] == 3]['age']    
plt.figure(figsize = (10,4))
plt.suptitle('Titanic Passenger ages')

plt.subplot(1,3,1)
plt.title('1st class')
plt.hist(first_class,label = 'first class',alpha = 0.8,bins = 20,color = 'blue')
plt.legend()

plt.subplot(1,3,2)
plt.title('2nd class')
plt.hist(second_class,label = 'second class',alpha = 0.8,bins = 20,color = 'red')
plt.legend()

plt.subplot(1,3,3)
plt.title('3rd class')
plt.hist(third_class,label = 'third class',alpha = 0.8,bins = 20,color = 'green')
plt.legend()

plt.tight_layout()
plt.show()

# %%
first_class = titanic[titanic['pclass'] == 1]['age']
second_class = titanic[titanic['pclass'] == 2]['age']
third_class = titanic[titanic['pclass'] == 3]['age']
plt.figure(figsize = (10,4))
plt.suptitle('Titanic Passenger ages')

ax = plt.subplot(1,3,1)
plt.title('1st class')
plt.hist(first_class,label = 'first class',alpha = 0.8,bins = 20,color = 'blue')
plt.legend()

plt.subplot(1,3,2,sharey = ax)
plt.title('2nd class')
plt.hist(second_class,label = 'second class',alpha = 0.8,bins = 20,color = 'red')
plt.legend()

plt.subplot(1,3,3,sharey = ax)
plt.title('3rd class')
plt.hist(third_class,label = 'third class',alpha = 0.8,bins = 20,color = 'green')
plt.legend()

plt.tight_layout()
plt.show()
