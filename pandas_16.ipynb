# %%
import pandas as pd

# %%
carstocks = pd.read_csv(r'D:\mygithub\data_visualization\data\car_stocks.csv')

# %%
titanic = pd.read_csv(r'D:\mygithub\data_visualization\data\titanic.csv')
titanic['age'] = titanic['age'].replace(['?'],[None])
titanic['age']
# Out:
# 0           29
# 1       0.9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14.5
# 1305      None
# 1306      26.5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
titanic['age'] = titanic['age'].astype('float')

# %%
titanic['age']
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
s1 = titanic.groupby('sex')['age'].mean()

# %%
s1.index
# Out:
# Index(['female', 'male'], dtype='object', name='sex')

# %%
titanic.groupby(['pclass','sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
df = titanic.groupby(['pclass','sex']).mean()

# %%
df.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df
# Out:
#                survived        age     sibsp     parch
# pclass sex
# 1      female  0.965278  37.037594  0.555556  0.472222
#        male    0.340782  41.029250  0.340782  0.279330
# 2      female  0.886792  27.499191  0.500000  0.650943
#        male    0.146199  30.815401  0.327485  0.192982
# 3      female  0.490741  22.185307  0.791667  0.731481
#        male    0.152130  25.962273  0.470588  0.255578

# %%
titanic.groupby(['sex','age']).mean()
# Out:
#                   pclass  survived     sibsp     parch
# sex    age
# female 0.1667   3.000000  1.000000  1.000000  2.000000
#        0.7500   3.000000  1.000000  2.000000  1.000000
#        0.9167   2.000000  1.000000  1.000000  2.000000
#        1.0000   2.800000  0.800000  0.800000  1.400000
#        2.0000   2.571429  0.285714  1.428571  1.428571
# ...                  ...       ...       ...       ...
# male   70.0000  1.500000  0.000000  0.500000  0.500000
#        70.5000  3.000000  0.000000  0.000000  0.000000
#        71.0000  1.000000  0.000000  0.000000  0.000000
#        74.0000  3.000000  0.000000  0.000000  0.000000
#        80.0000  1.000000  1.000000  0.000000  0.000000
#
# [166 rows x 4 columns]

# %%
pops = pd.read_csv(r'D:\mygithub\data_visualization\data\state_pops.csv')

# %%
pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.index
# Doesn't represent anything yet
# Out:
# RangeIndex(start=0, stop=1272, step=1)

# %%
pops.set_index('state').loc['USA']
# Out:
#        year   population
# state
# USA    1990  249622814.0
# USA    1991  252980942.0
# USA    1992  256514231.0
# USA    1993  259918595.0
# USA    1994  263125826.0
# USA    1995  266278403.0
# USA    1996  269394291.0
# USA    1997  272646932.0
# USA    1998  275854116.0
# USA    2000  282162411.0
# USA    1999  279040181.0
# USA    2001  284968955.0
# USA    2002  287625193.0
# USA    2003  290107933.0
# USA    2004  292805298.0
# USA    2005  295516599.0
# USA    2006  298379912.0
# USA    2007  301231207.0
# USA    2008  304093966.0
# USA    2013  316128839.0
# USA    2009  306771529.0
# USA    2010  309326295.0
# USA    2011  311582564.0
# USA    2012  313873685.0

# %%
pops.set_index('year').loc[2010]
# Out:
#      state   population
# year
# 2010    AL    4785570.0
# 2010    AK     713868.0
# 2010    AZ    6408790.0
# 2010    AR    2922280.0
# 2010    CA   37333601.0
# 2010    CO    5048196.0
# 2010    CT    3579210.0
# 2010    DE     899711.0
# 2010    DC     605125.0
# 2010    FL   18846054.0
# 2010    GA    9713248.0
# 2010    HI    1363731.0
# 2010    ID    1570718.0
# 2010    IL   12839695.0
# 2010    IN    6489965.0
# 2010    IA    3050314.0
# 2010    KS    2858910.0
# 2010    KY    4347698.0
# 2010    LA    4545392.0
# 2010    ME    1327366.0
# 2010    MD    5787193.0
# 2010    MA    6563263.0
# 2010    MI    9876149.0
# 2010    MN    5310337.0
# 2010    MS    2970047.0
# 2010    MO    5996063.0
# 2010    MT     990527.0
# 2010    NE    1829838.0
# 2010    NV    2703230.0
# 2010    NH    1316614.0
# 2010    NJ    8802707.0
# 2010    NM    2064982.0
# 2010    NY   19398228.0
# 2010    NC    9559533.0
# 2010    ND     674344.0
# 2010    OH   11545435.0
# 2010    OK    3759263.0
# ...

# %%
pops.set_index(['state','year'],inplace = True)

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.index
# Out:
# MultiIndex([( 'AL', 2012),
#             ( 'AL', 2010),
#             ( 'AL', 2011),
#             ( 'AL', 2009),
#             ( 'AL', 2013),
#             ( 'AL', 2007),
#             ( 'AL', 2008),
#             ( 'AL', 2005),
#             ( 'AL', 2006),
#             ( 'AL', 2004),
#             ...
#             ('USA', 2004),
#             ('USA', 2005),
#             ('USA', 2006),
#             ('USA', 2007),
#             ('USA', 2008),
#             ('USA', 2013),
#             ('USA', 2009),
#             ('USA', 2010),
#             ('USA', 2011),
#             ('USA', 2012)],
#            names=['state', 'year'], length=1272)

# %%
pops.sort_index()
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(ascending=False)
# Out:
#             population
# state year
# WY    2013    582658.0
#       2012    576626.0
#       2011    567329.0
#       2010    564222.0
#       2009    559851.0
# ...                ...
# AK    1994    603308.0
#       1993    599434.0
#       1992    588736.0
#       1991    570193.0
#       1990    553290.0
#
# [1272 rows x 1 columns]

# %%
# Tab law 3ayz a3mel sort le wahed bas mn el index ely 3andy a3mel ehh ?
pops.sort_index(level = 1) # ana kda 3amlt lel year bas sort
# Out:
#             population
# state year
# AK    1990    553290.0
# AL    1990   4050055.0
# AR    1990   2356586.0
# AZ    1990   3684097.0
# CA    1990  29959515.0
# ...                ...
# VT    2013    626630.0
# WA    2013   6971406.0
# WI    2013   5742713.0
# WV    2013   1854304.0
# WY    2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(ascending=[False,True],level = [0,1])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.loc['NV']
# Out:
#       population
# year
# 1990   1220695.0
# 1991   1296172.0
# 1992   1351367.0
# 1993   1411215.0
# 1994   1499298.0
# 1995   1581578.0
# 1996   1666320.0
# 1997   1764104.0
# 1998   1853192.0
# 1999   1934718.0
# 2000   2018741.0
# 2001   2098399.0
# 2002   2173791.0
# 2003   2248850.0
# 2004   2346222.0
# 2005   2432143.0
# 2006   2522658.0
# 2007   2601072.0
# 2008   2653630.0
# 2009   2684665.0
# 2010   2703230.0
# 2011   2717951.0
# 2012   2754354.0
# 2013   2790136.0

# %%
df = pops.sort_index(ascending=[False,False],level = [0,1]).loc['AK':'WY']
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# d:\mygithub\data_visualization\pandas_16.ipynb Cell 35 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/mygithub/data_visualization/pandas_16.ipynb#X50sZmlsZQ%3D%3D?line=0'>1</a> df = pops.sort_index(ascending=[False,False],level = [0,1]).loc['AK':'WY']
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1183, in _LocIndexer._getitem_axis(self, key, axis)
#    1181 if isinstance(key, slice):
#    1182     self._validate_key(key, axis)
# ...

# %% [markdown]
# ## In order to use the slicing, the index needs to be in sorted order.

# %%
pops.sort_index(inplace=True)

# %%
pops.loc['NM':'TX']
# Out:
#             population
# state year
# NM    1990   1521574.0
#       1991   1555305.0
#       1992   1595442.0
#       1993   1636453.0
#       1994   1682398.0
# ...                ...
# TX    2009  24801761.0
#       2010  25245178.0
#       2011  25640909.0
#       2012  26060796.0
#       2013  26448193.0
#
# [312 rows x 1 columns]

# %%
df.sort_index().loc['AK':'WY']
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[['AK','NV']]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
#       1996    608569.0
#       1997    612968.0
#       1998    619933.0
#       1999    624779.0
#       2000    627963.0
#       2001    633714.0
#       2002    642337.0
#       2003    648414.0
#       2004    659286.0
#       2005    666946.0
#       2006    675302.0
#       2007    680300.0
#       2008    687455.0
#       2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
# NV    1990   1220695.0
#       1991   1296172.0
#       1992   1351367.0
#       1993   1411215.0
#       1994   1499298.0
#       1995   1581578.0
#       1996   1666320.0
#       1997   1764104.0
#       1998   1853192.0
#       1999   1934718.0
#       2000   2018741.0
#       2001   2098399.0
#       2002   2173791.0
#       2003   2248850.0
# ...

# %%
pops.loc[('MT',1992)]
# Out:
# population    825770.0
# Name: (MT, 1992), dtype: float64

# %%
pops.loc[("CA",2013)]
# Out:
# population    38332521.0
# Name: (CA, 2013), dtype: float64

# %%
pops.loc[('AK',1990):('AK',1995)]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.loc[('AK',2011):('AL',1993)]
# Out:
#             population
# state year
# AK    2011    723375.0
#       2012    730307.0
#       2013    735132.0
# AL    1990   4050055.0
#       1991   4099156.0
#       1992   4154014.0
#       1993   4214202.0

# %%
pops.loc[:,1990]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Hossam\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1990
#
# ...

# %%
titanic.loc[19,'name']
# Out:
# 'Beattie, Mr. Thomson'

# %% [markdown]
# ### level 0,level 1,columns

# %%
pops.loc[:,1990,:]
# Out:
#         population
# state
# AK        553290.0
# AL       4050055.0
# AR       2356586.0
# AZ       3684097.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DC        605321.0
# DE        669567.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# IA       2781018.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# MA       6022639.0
# MD       4799770.0
# ME       1231719.0
# MI       9311319.0
# MN       4389857.0
# MO       5128880.0
# MS       2578897.0
# MT        800204.0
# NC       6664016.0
# ND        637685.0
# NE       1581660.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NV       1220695.0
# NY      18020784.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# PR             NaN
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# USA    249622814.0
# ...

# %%
pops.loc[:,[1990,1992],:]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
# AL    1990   4050055.0
#       1992   4154014.0
# AR    1990   2356586.0
# ...                ...
# WI    1992   5025398.0
# WV    1990   1792548.0
#       1992   1806451.0
# WY    1990    453690.0
#       1992    466251.0
#
# [106 rows x 1 columns]

# %%
pops.loc[:,1990:1998,:]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    1994    480283.0
#       1995    485160.0
#       1996    488167.0
#       1997    489452.0
#       1998    490787.0
#
# [477 rows x 1 columns]

# %%
pops.loc[['AK','CA'],1990:1992,:]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
# CA    1990  29959515.0
#       1991  30470736.0
#       1992  30974659.0

# %%
pops.loc[slice(None),1990:1998,:]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    1994    480283.0
#       1995    485160.0
#       1996    488167.0
#       1997    489452.0
#       1998    490787.0
#
# [477 rows x 1 columns]

# %%
pops.loc[:,2013,:]
# Out:
#         population
# state
# AK        735132.0
# AL       4833722.0
# AR       2959373.0
# AZ       6626624.0
# CA      38332521.0
# CO       5268367.0
# CT       3596080.0
# DC        646449.0
# DE        925749.0
# FL      19552860.0
# GA       9992167.0
# HI       1404054.0
# IA       3090416.0
# ID       1612136.0
# IL      12882135.0
# IN       6570902.0
# KS       2893957.0
# KY       4395295.0
# LA       4625470.0
# MA       6692824.0
# MD       5928814.0
# ME       1328302.0
# MI       9895622.0
# MN       5420380.0
# MO       6044171.0
# MS       2991207.0
# MT       1015165.0
# NC       9848060.0
# ND        723393.0
# NE       1868516.0
# NH       1323459.0
# NJ       8899339.0
# NM       2085287.0
# NV       2790136.0
# NY      19651127.0
# OH      11570808.0
# OK       3850568.0
# OR       3930065.0
# PA      12773801.0
# PR       3615086.0
# RI       1051511.0
# SC       4774839.0
# SD        844877.0
# TN       6495978.0
# TX      26448193.0
# USA    316128839.0
# ...

# %%
pops.xs(2013,level = 'year')
# Out:
#         population
# state
# AK        735132.0
# AL       4833722.0
# AR       2959373.0
# AZ       6626624.0
# CA      38332521.0
# CO       5268367.0
# CT       3596080.0
# DC        646449.0
# DE        925749.0
# FL      19552860.0
# GA       9992167.0
# HI       1404054.0
# IA       3090416.0
# ID       1612136.0
# IL      12882135.0
# IN       6570902.0
# KS       2893957.0
# KY       4395295.0
# LA       4625470.0
# MA       6692824.0
# MD       5928814.0
# ME       1328302.0
# MI       9895622.0
# MN       5420380.0
# MO       6044171.0
# MS       2991207.0
# MT       1015165.0
# NC       9848060.0
# ND        723393.0
# NE       1868516.0
# NH       1323459.0
# NJ       8899339.0
# NM       2085287.0
# NV       2790136.0
# NY      19651127.0
# OH      11570808.0
# OK       3850568.0
# OR       3930065.0
# PA      12773801.0
# PR       3615086.0
# RI       1051511.0
# SC       4774839.0
# SD        844877.0
# TN       6495978.0
# TX      26448193.0
# USA    316128839.0
# ...

# %%
pops.xs(2013,level = 1)
# Out:
#         population
# state
# AK        735132.0
# AL       4833722.0
# AR       2959373.0
# AZ       6626624.0
# CA      38332521.0
# CO       5268367.0
# CT       3596080.0
# DC        646449.0
# DE        925749.0
# FL      19552860.0
# GA       9992167.0
# HI       1404054.0
# IA       3090416.0
# ID       1612136.0
# IL      12882135.0
# IN       6570902.0
# KS       2893957.0
# KY       4395295.0
# LA       4625470.0
# MA       6692824.0
# MD       5928814.0
# ME       1328302.0
# MI       9895622.0
# MN       5420380.0
# MO       6044171.0
# MS       2991207.0
# MT       1015165.0
# NC       9848060.0
# ND        723393.0
# NE       1868516.0
# NH       1323459.0
# NJ       8899339.0
# NM       2085287.0
# NV       2790136.0
# NY      19651127.0
# OH      11570808.0
# OK       3850568.0
# OR       3930065.0
# PA      12773801.0
# PR       3615086.0
# RI       1051511.0
# SC       4774839.0
# SD        844877.0
# TN       6495978.0
# TX      26448193.0
# USA    316128839.0
# ...

# %%
pops.xs('AK',level = 0)
# Out:
#       population
# year
# 1990    553290.0
# 1991    570193.0
# 1992    588736.0
# 1993    599434.0
# 1994    603308.0
# 1995    604412.0
# 1996    608569.0
# 1997    612968.0
# 1998    619933.0
# 1999    624779.0
# 2000    627963.0
# 2001    633714.0
# 2002    642337.0
# 2003    648414.0
# 2004    659286.0
# 2005    666946.0
# 2006    675302.0
# 2007    680300.0
# 2008    687455.0
# 2009    698895.0
# 2010    713868.0
# 2011    723375.0
# 2012    730307.0
# 2013    735132.0

# %%
pops.index.levels
# Out:
# FrozenList([['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'USA', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]])

# %%
pops.index.get_level_values(level = 0)
# Out:
# Index(['AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK', 'AK',
#        ...
#        'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY', 'WY'],
#       dtype='object', name='state', length=1272)

# %%
pops.index.get_level_values(1)
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#             ...
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013],
#            dtype='int64', name='year', length=1272)

# %%
pops.index.get_level_values(0)[9]
# Out:
# 'AK'

# %%
even_years = pops.index.get_level_values(level = 1) % 2 == 0

# %%
even_years
# Out:
# array([ True, False,  True, ..., False,  True, False])

# %%
even_pops = pops['population'] % 2 == 0

# %%
pops[even_years & even_pops]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
#       1994    603308.0
#       2004    659286.0
#       2006    675302.0
# ...                ...
# WY    1990    453690.0
#       2000    494300.0
#       2004    509106.0
#       2010    564222.0
#       2012    576626.0
#
# [304 rows x 1 columns]

# %%
ends_with_a = pops.index.get_level_values(level  = 0).str[1] == 'A'

# %%
pops[ends_with_a]
# Out:
#             population
# state year
# CA    1990  29959515.0
#       1991  30470736.0
#       1992  30974659.0
#       1993  31274928.0
#       1994  31484435.0
# ...                ...
# WA    2009   6667426.0
#       2010   6742256.0
#       2011   6821481.0
#       2012   6895318.0
#       2013   6971406.0
#
# [192 rows x 1 columns]

# %%
dff = titanic.groupby('sex').agg({'age':['mean','min','max'], })

# %%
dff
# Out:
#               age
#              mean     min   max
# sex
# female  28.687071  0.1667  76.0
# male    30.585233  0.3333  80.0

# %%
dff['age','mean']
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: (age, mean), dtype: float64

# %%
pops
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.unstack()
# Out:
#         population                                                      \
# year          1990         1991         1992         1993         1994
# state
# AK        553290.0     570193.0     588736.0     599434.0     603308.0
# AL       4050055.0    4099156.0    4154014.0    4214202.0    4260229.0
# AR       2356586.0    2383144.0    2415984.0    2456303.0    2494019.0
# AZ       3684097.0    3788576.0    3915740.0    4065440.0    4245089.0
# CA      29959515.0   30470736.0   30974659.0   31274928.0   31484435.0
# CO       3307618.0    3387119.0    3495939.0    3613734.0    3724168.0
# CT       3291967.0    3302895.0    3300712.0    3309175.0    3316121.0
# DC        605321.0     600870.0     597567.0     595302.0     589240.0
# DE        669567.0     683080.0     694927.0     706378.0     717545.0
# FL      13033307.0   13369798.0   13650553.0   13927185.0   14239444.0
# GA       6512602.0    6653005.0    6817203.0    6978240.0    7157165.0
# ...

# %%
pops.unstack(level = 'state')
# Out:
#       population                                                          \
# state         AK         AL         AR         AZ          CA         CO
# year
# 1990    553290.0  4050055.0  2356586.0  3684097.0  29959515.0  3307618.0
# 1991    570193.0  4099156.0  2383144.0  3788576.0  30470736.0  3387119.0
# 1992    588736.0  4154014.0  2415984.0  3915740.0  30974659.0  3495939.0
# 1993    599434.0  4214202.0  2456303.0  4065440.0  31274928.0  3613734.0
# 1994    603308.0  4260229.0  2494019.0  4245089.0  31484435.0  3724168.0
# 1995    604412.0  4296800.0  2535399.0  4432499.0  31696582.0  3826653.0
# 1996    608569.0  4331103.0  2572109.0  4586940.0  32018834.0  3919972.0
# 1997    612968.0  4367935.0  2601091.0  4736990.0  32486010.0  4018293.0
# 1998    619933.0  4404701.0  2626289.0  4883342.0  32987675.0  4116639.0
# 1999    624779.0  4430141.0  2651860.0  5023823.0  33499204.0  4226018.0
# 2000    627963.0  4452173.0  2678588.0  5160586.0  33987977.0  4326921.0
# ...

# %%
unstacked = pops.unstack(level = 'state')

# %%
unstacked.stack()
# Out:
#             population
# year state
# 1990 AK       553290.0
#      AL      4050055.0
#      AR      2356586.0
#      AZ      3684097.0
#      CA     29959515.0
# ...                ...
# 2013 VT       626630.0
#      WA      6971406.0
#      WI      5742713.0
#      WV      1854304.0
#      WY       582658.0
#
# [1262 rows x 1 columns]

# %%
titanic.groupby(['pclass','sex'])['age'].mean()
# Out:
# pclass  sex
# 1       female    37.037594
#         male      41.029250
# 2       female    27.499191
#         male      30.815401
# 3       female    22.185307
#         male      25.962273
# Name: age, dtype: float64

# %%
titanic.groupby(['pclass','sex'])['age'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack()
# Out:
# sex        female       male
# pclass
# 1       37.037594  41.029250
# 2       27.499191  30.815401
# 3       22.185307  25.962273

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby(['pclass','sex'])['age'].mean().unstack(level = 'pclass').plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(['sex','survived'])['age'].mean()
# Out:
# sex     survived
# female  0           25.255208
#         1           29.815354
# male    0           31.516412
#         1           26.977778
# Name: age, dtype: float64

# %%
titanic.groupby(['sex','survived'])['age'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sex,survived'>

# %%
titanic.groupby(['sex','survived'])['age'].mean().unstack(level = 0).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='survived'>

# %%
titanic.groupby(['sex','survived'])['age'].mean().unstack().rename(columns = {0:'Died',1:'Survived'}).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
pops
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.groupby(level = 1).sum()
# Out:
#        population
# year
# 1990  499245628.0
# 1991  505961884.0
# 1992  513028462.0
# 1993  519837190.0
# 1994  526251652.0
# 1995  532556806.0
# 1996  538788582.0
# 1997  545293864.0
# 1998  551708232.0
# 1999  558080362.0
# 2000  568135427.0
# 2001  573756684.0
# 2002  579074087.0
# 2003  584041961.0
# 2004  589437474.0
# 2005  594854560.0
# 2006  600565038.0
# 2007  606245409.0
# 2008  611948798.0
# 2009  617283468.0
# 2010  622373798.0
# 2011  626851708.0
# 2012  631398915.0
# 2013  635872764.0

# %%
pops.groupby(level = [1,0]).min()
# Out:
#             population
# year state
# 1990 AK       553290.0
#      AL      4050055.0
#      AR      2356586.0
#      AZ      3684097.0
#      CA     29959515.0
# ...                ...
# 2013 VT       626630.0
#      WA      6971406.0
#      WI      5742713.0
#      WV      1854304.0
#      WY       582658.0
#
# [1272 rows x 1 columns]
