# %%
import pandas as pd
titanic = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\titanic.csv')
houses = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\kc_house_data.csv")
netflix = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\netflix_titles.csv",sep='|',index_col =0)
btc = pd.read_csv(r"C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\coin_Bitcoin.csv")
countries = pd.read_csv(r'C:\Users\Hossam\Desktop\data visualiztion\DataAnalysisCourseMaterials\DataAnalysis\data\world-happiness-report-2021.csv')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
countries.set_index('Country name', inplace = True)

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.drop(labels= ['Symbol','SNo'],axis = 1)
# Out:
#          Name                 Date          High           Low          Open  \
# 0     Bitcoin  2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     Bitcoin  2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     Bitcoin  2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     Bitcoin  2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     Bitcoin  2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...       ...                  ...           ...           ...           ...
# 2986  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
# ...

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.drop(columns = ['SNo','Name','Symbol'])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(labels = 'Finland',axis =0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(['Finland','Denmark','Switzerland'])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
# if u want to drop many columns >>> make a new dataframe w engz 
btc[['High','Low']]
# Out:
#               High           Low
# 0       147.488007    134.000000
# 1       146.929993    134.050003
# 2       139.889999    107.720001
# 3       125.599998     92.281898
# 4       108.127998     79.099998
# ...            ...           ...
# 2986  33939.588699  32770.680780
# 2987  34909.259899  33402.696536
# 2988  35937.567147  34396.477458
# 2989  35284.344430  33213.661034
# 2990  35038.536363  33599.916169
#
# [2991 rows x 2 columns]

# %%
btc.sort_index(ascending=False,inplace = True)

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# ...    ...      ...    ...                  ...           ...           ...
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#
# ...

# %%
btc.drop(2990)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  35035.982712  32883.781226
# ...    ...      ...    ...                  ...           ...           ...
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
# adding static column
titanic['static'] = "Human"
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.insert(0,'county','God Save the King')

# %%
houses
# Out:
#                   county          id             date     price  bedrooms  \
# 0      God Save the King  7129300520  20141013T000000  221900.0         3
# 1      God Save the King  6414100192  20141209T000000  538000.0         3
# 2      God Save the King  5631500400  20150225T000000  180000.0         2
# 3      God Save the King  2487200875  20141209T000000  604000.0         4
# 4      God Save the King  1954400510  20150218T000000  510000.0         3
# ...                  ...         ...              ...       ...       ...
# 21608  God Save the King   263000018  20140521T000000  360000.0         3
# 21609  God Save the King  6600060120  20150223T000000  400000.0         4
# 21610  God Save the King  1523300141  20140623T000000  402101.0         2
# 21611  God Save the King   291310100  20150116T000000  400000.0         3
# 21612  God Save the King  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# ...

# %%
houses.insert(3,'num_bedrooms',houses['bedrooms'])
houses
# Out:
#                   county          id             date  num_bedrooms     price  \
# 0      God Save the King  7129300520  20141013T000000             3  221900.0
# 1      God Save the King  6414100192  20141209T000000             3  538000.0
# 2      God Save the King  5631500400  20150225T000000             2  180000.0
# 3      God Save the King  2487200875  20141209T000000             4  604000.0
# 4      God Save the King  1954400510  20150218T000000             3  510000.0
# ...                  ...         ...              ...           ...       ...
# 21608  God Save the King   263000018  20140521T000000             3  360000.0
# 21609  God Save the King  6600060120  20150223T000000             4  400000.0
# 21610  God Save the King  1523300141  20140623T000000             2  402101.0
# 21611  God Save the King   291310100  20150116T000000             3  400000.0
# 21612  God Save the King  1523300157  20141015T000000             2  325000.0
#
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.insert(len(titanic.columns),'species','Human')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.drop(columns = 'species',inplace = True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['parch']
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic['sibsp']
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic['sibsp'] + titanic['parch']
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic['num_relatives'] = titanic['sibsp'] + titanic['parch']

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values('num_relatives',ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic[titanic['survived'] == 1].sort_values('num_relatives',ascending = False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic['num_relatives'] == 0
titanic[solo_passengers].pclass.value_counts()
# Out:
# 3    472
# 1    160
# 2    158
# Name: pclass, dtype: int64

# %%
titanic[solo_passengers].sex.value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
titanic['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
houses
# Out:
#                   county          id             date  num_bedrooms     price  \
# 0      God Save the King  7129300520  20141013T000000             3  221900.0
# 1      God Save the King  6414100192  20141209T000000             3  538000.0
# 2      God Save the King  5631500400  20150225T000000             2  180000.0
# 3      God Save the King  2487200875  20141209T000000             4  604000.0
# 4      God Save the King  1954400510  20150218T000000             3  510000.0
# ...                  ...         ...              ...           ...       ...
# 21608  God Save the King   263000018  20140521T000000             3  360000.0
# 21609  God Save the King  6600060120  20150223T000000             4  400000.0
# 21610  God Save the King  1523300141  20140623T000000             2  402101.0
# 21611  God Save the King   291310100  20150116T000000             3  400000.0
# 21612  God Save the King  1523300157  20141015T000000             2  325000.0
#
# ...

# %%
houses['price_sqft']  = houses['price'] / houses['sqft_living']

# %%
houses
# Out:
#                   county          id             date  num_bedrooms     price  \
# 0      God Save the King  7129300520  20141013T000000             3  221900.0
# 1      God Save the King  6414100192  20141209T000000             3  538000.0
# 2      God Save the King  5631500400  20150225T000000             2  180000.0
# 3      God Save the King  2487200875  20141209T000000             4  604000.0
# 4      God Save the King  1954400510  20150218T000000             3  510000.0
# ...                  ...         ...              ...           ...       ...
# 21608  God Save the King   263000018  20140521T000000             3  360000.0
# 21609  God Save the King  6600060120  20150223T000000             4  400000.0
# 21610  God Save the King  1523300141  20140623T000000             2  402101.0
# 21611  God Save the King   291310100  20150116T000000             3  400000.0
# 21612  God Save the King  1523300157  20141015T000000             2  325000.0
#
# ...

# %%
houses.sort_values('price_sqft',ascending=False).head(5)
# Out:
#                   county          id             date  num_bedrooms  \
# 19336  God Save the King  6021500970  20150407T000000             2
# 4013   God Save the King   724069059  20140509T000000             3
# 10446  God Save the King  1118000320  20150508T000000             4
# 8623   God Save the King  6303400395  20150130T000000             1
# 9314   God Save the King  4389200610  20141201T000000             2
#
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  \
# 19336   874950.0         2       1.00         1080      4000     1.0  ...
# 4013   2400000.0         3       2.25         3000     11665     1.5  ...
# 10446  3400000.0         4       4.00         4260     11765     2.0  ...
# 8623    325000.0         1       0.75          410      8636     1.0  ...
# 9314    903000.0         2       1.50         1140      7800     1.0  ...
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
houses.sort_values('price_sqft',ascending =False).head(50).zipcode.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
btc.describe(include ='all')
# Out:
#                 SNo     Name Symbol                 Date          High  \
# count   2991.000000     2991   2991                 2991   2991.000000
# unique          NaN        1      1                 2991           NaN
# top             NaN  Bitcoin    BTC  2021-07-06 23:59:59           NaN
# freq            NaN     2991   2991                    1           NaN
# mean    1496.000000      NaN    NaN                  NaN   6893.326038
# std      863.571653      NaN    NaN                  NaN  11642.832456
# min        1.000000      NaN    NaN                  NaN     74.561096
# 25%      748.500000      NaN    NaN                  NaN    436.179001
# 50%     1496.000000      NaN    NaN                  NaN   2387.610107
# 75%     2243.500000      NaN    NaN                  NaN   8733.926948
# max     2991.000000      NaN    NaN                  NaN  64863.098908
#
#                  Low          Open         Close        Volume     Marketcap
# ...

# %%
btc.drop(columns = ['SNo','Name','Symbol'],inplace = True)

# %%
btc.set_index('Date',inplace=True)

# %%
btc['change'] = btc['Close'] - btc['Open']

# %%
btc.sort_values('change',ascending=False)
# Out:
#                              High           Low          Open         Close  \
# Date
# 2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290  46196.463719
# 2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363  54021.754787
# 2021-03-01 23:59:59  49784.015290  45115.093115  45159.503053  49631.241371
# 2021-02-19 23:59:59  56113.650547  50937.275722  51675.981285  55888.133682
# 2021-04-30 23:59:59  57900.719988  53129.600877  53568.663584  57750.177346
# ...                           ...           ...           ...           ...
# 2021-04-18 23:59:59  61057.456509  52829.535926  60701.886093  56216.185002
# 2021-01-21 23:59:59  35552.679497  30250.749639  35549.397409  30825.698506
# 2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756  48824.426869
# 2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447  37002.440466
# 2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167  49150.533875
#
# ...

# %%
btc['delta'] = btc['High'] - btc['Low']
btc.sort_values('delta',ascending = False).head(10)['delta'].plot(kind ='bar')
# Out:
# <AxesSubplot:xlabel='Date'>
